# %%
import numpy as np
import pandas as pd
import datetime

from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 依照參數回傳每人的資料
# 輸入格式(資料名(combined), 年, 季(1 -> 1~3月 ...))

# %%
def get_season(combined, y, s):
    if s == 4:
        lower = str(y)+'-10-01'
        upper = str(y+1)+'-01-01'
    elif s == 3:
        lower = str(y)+'-07-01'
        upper = str(y)+'-10-01'
    elif s == 1:
        lower = str(y)+'-01-01'
        upper = str(y)+'-04-01'
    elif s == 2:
        lower = str(y)+'-04-01'
        upper = str(y)+'-07-01'
    else:
        print('s must be 1, 2, 3 or 4')
        return 0
    print(lower, upper)
    
    ids = combined['UnifiedUserId'].unique()
    combined = combined[(combined['OrderDateTime'] < upper) & (combined['OrderDateTime'] > lower)]
  
    lst = []
    for i in ids:
        ele = {'UnifiedUserId': i,
               'MemberCardLevel': 0,
               'Gender': 'Ungiven',
               'Age': 0,
               'order': 0, #本季主單數
               'orderSlave': 0, #本季子單數
               'low': 0, #本季低價位商品購買數
               'normal': 0, #本季中價位商品購買數
               'high': 0, #本季高價位商品購買數
               'sales': 0,# 本季總消費
               'SalePageId':""
                }
        lst.append(ele)
        
    re = pd.DataFrame(lst).set_index('UnifiedUserId').copy()
    
    for index, r in combined.iterrows():
        idx = r['UnifiedUserId']
        re.loc.__setitem__((idx, ('Gender')), r['Gender'])
        re.loc.__setitem__((idx, ('MemberCardLevel')), r['MemberCardLevel'])
        re.loc.__setitem__((idx, ('Age')), int((datetime.datetime.today() - datetime.datetime.strptime(r['Birthday'], '%Y-%m-%d')).days/365))
        re.loc.__setitem__((idx, ('orderSlave')), r['TsCount'] + re.loc[idx]['orderSlave'])
        re.loc.__setitem__((idx, ('order')), 1 + re.loc[idx]['order'])
        re.loc.__setitem__((idx, ('sales')), r['TotalSalesAmount'] + re.loc[idx]['sales'])
        re.loc.__setitem__((idx, ('high')), r['high'] + re.loc[idx]['high'])
        re.loc.__setitem__((idx, ('normal')), r['normal'] + re.loc[idx]['normal'])
        re.loc.__setitem__((idx, ('low')), r['low'] + re.loc[idx]['low'])
        re.loc.__setitem__((idx, ('SalePageId')), r['SalePageId'] + "/" + re.loc[idx]['SalePageId'])
        
    re['avgSales'] = re['sales']/re['order']
                    
    return re

# %% [markdown]
# ## 讀取資料

# %%
member = pd.read_csv('91APP_MemberData.csv')
order = pd.read_csv('91APP_OrderData.csv')
product = pd.read_excel("user_tag.xlsx").dropna()
# Out:
# C:\Users\lawre\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
member = member[['UnifiedUserId', 'Gender', 'Birthday', 'MemberCardLevel']]
member.head(3)
# Out:
#               UnifiedUserId  Gender    Birthday  MemberCardLevel
# 0  wDnLYnQDE5Nt/TBttarrEw==  Female  1987-11-12               10
# 1  PfTmZ2HBNiyYJrv0kLZpnw==  Female  1990-09-02               10
# 2  MajPkebcNSUBGwNtJOjVMA==  Female  1985-09-08               10

# %%
order = order[['TradesGroupCode', 'OrderDateTime', 'TsCount', 'Qty', 'TotalSalesAmount']]
order.head(3)
# Out:
#                                 TradesGroupCode        OrderDateTime  TsCount  \
# 0  5uPmVe+VOTmLhDIRYqZ0X9WEZkAr2lq1GaDvxM2C/fw=  2016-04-29 09:56:00        1
# 1  5uPmVe+VOTmLhDIRYqZ0X9WEZkAr2lq1GaDvxM2C/fw=  2016-04-29 09:56:00        2
# 2  VTI/4oAuHAlVolhrBpXzm/k7eAzdN4fsM2NjCE6YLEI=  2016-04-29 11:04:00        1
#
#    Qty  TotalSalesAmount
# 0   -1            -100.0
# 1    2            1284.0
# 2    1            1184.0

# %%
product.head(3)
# Out:
#    Unnamed: 0                               TradesGroupCode SalePageId
# 0         2.0  Esf9q59OO5QVU6Rapl8m7t8Lyu1MshueQOEyRRXEwU8=        小白鞋
# 1         5.0  wTDcVew4UUsw/a9ag6EtoIKd4dp+bPyvV3n7jJZag0w=       菱格紋包
# 2         6.0  3uq44BE2pVcqbv+OgCeNtBQycM8O7Ncy6cqzWo/Wbew=       鞋用配件

# %%
df = pd.read_csv('data.csv')[['UnifiedUserId', 'TradesGroupCode', 'low', 'normal', 'high']]

# %%
df.head(3)
# Out:
#               UnifiedUserId                               TradesGroupCode  \
# 0  xjOctGt+CvE/+soyAS+LVA==  5uPmVe+VOTmLhDIRYqZ0X9WEZkAr2lq1GaDvxM2C/fw=
# 1  Agoqyv2QhggU0nmPX6tVJA==  VTI/4oAuHAlVolhrBpXzm/k7eAzdN4fsM2NjCE6YLEI=
# 2  xvZqF1Tlc8cGPJQwyRT24A==  BmdhnTN8wcHjLbMp8O3awDOib/WiGtv9yazSs3H5Jnk=
#
#    low  normal  high
# 0    1       1     0
# 1    0       1     0
# 2    1       0     0

# %% [markdown]
# ## 在每個主單中加入 1)高價位單品數 2)中價位單品數 3)低價位的單品數

# %% [markdown]
# 所有子單單價的前25%為高價位，中間50%為中價位，後25%為低價位 (不含0圓商品)

# %%
combine = pd.merge(order, df, left_on = 'TradesGroupCode', right_on = 'TradesGroupCode', how = 'left')

# %%
combine.head(3)
# Out:
#                                 TradesGroupCode        OrderDateTime  TsCount  \
# 0  5uPmVe+VOTmLhDIRYqZ0X9WEZkAr2lq1GaDvxM2C/fw=  2016-04-29 09:56:00        1
# 1  5uPmVe+VOTmLhDIRYqZ0X9WEZkAr2lq1GaDvxM2C/fw=  2016-04-29 09:56:00        2
# 2  VTI/4oAuHAlVolhrBpXzm/k7eAzdN4fsM2NjCE6YLEI=  2016-04-29 11:04:00        1
#
#    Qty  TotalSalesAmount             UnifiedUserId  low  normal  high
# 0   -1            -100.0  xjOctGt+CvE/+soyAS+LVA==  1.0     1.0   0.0
# 1    2            1284.0  xjOctGt+CvE/+soyAS+LVA==  1.0     1.0   0.0
# 2    1            1184.0  Agoqyv2QhggU0nmPX6tVJA==  0.0     1.0   0.0

# %%
combined = pd.merge(combine, member, left_on = 'UnifiedUserId', right_on = 'UnifiedUserId', how = 'left')

# %%
combined = combined[combined['Qty'] >= 0]

# %%
combined.head()
# Out:
#                                 TradesGroupCode        OrderDateTime  TsCount  \
# 1  5uPmVe+VOTmLhDIRYqZ0X9WEZkAr2lq1GaDvxM2C/fw=  2016-04-29 09:56:00        2
# 2  VTI/4oAuHAlVolhrBpXzm/k7eAzdN4fsM2NjCE6YLEI=  2016-04-29 11:04:00        1
# 3  BmdhnTN8wcHjLbMp8O3awDOib/WiGtv9yazSs3H5Jnk=  2016-04-29 11:05:00        1
# 4  AlDaYlS/Oda/FRWZqGNt1kV4N6UhQ0tNbA2y7lmS5pI=  2016-05-02 10:29:00        1
# 5  LZqYjv3x9IzUf5jNUtFz/3vijWR+KcTn3RzfTQF2yXs=  2016-05-03 10:29:00        2
#
#    Qty  TotalSalesAmount             UnifiedUserId  low  normal  high  Gender  \
# 1    2            1284.0  xjOctGt+CvE/+soyAS+LVA==  1.0     1.0   0.0     NaN
# 2    1            1184.0  Agoqyv2QhggU0nmPX6tVJA==  0.0     1.0   0.0     NaN
# 3    1            1184.0  xvZqF1Tlc8cGPJQwyRT24A==  1.0     0.0   0.0     NaN
# 4    1            1080.0  R+nvCLvUXeVCC4OYsSjSzA==  0.0     1.0   0.0  Female
# 5    2            1774.0  ftOkl2eeDxYeBcSZX3UiTA==  1.0     1.0   0.0  Female
#
#      Birthday  MemberCardLevel
# 1  1900-01-01             10.0
# 2  0001-01-01             10.0
# 3  1900-01-01             10.0
# 4  1984-06-05             10.0
# 5  0076-09-25             10.0

# %%
l = []
for i in combined['OrderDateTime']:
    l.append(i.split()[0])
combined['OrderDateTime'] = l

# %%
ProductTag = list(product["SalePageId"].unique())
print(ProductTag)
# Out:
# ['小白鞋', '菱格紋包', '鞋用配件', '短靴', '拖鞋', '贈品', '跟鞋', '婚鞋', '膝靴', 'NG鞋', '身體保養', '鞋墊', '老爹鞋', '涼拖鞋', '穆勒鞋', '牛津鞋', '日用品', '厚底鞋', '尖頭鞋', '帆布鞋', '涼鞋', '長靴', '襪靴', '便鞋', '平底鞋', '小包', '皮夾x卡夾x零錢包', '紳士鞋', '服裝衣物', '懶人鞋', '休閒鞋', '包鞋', '飾品配件', '黛妃包', '包用配件', '凱莉包', '高跟鞋', '草編鞋', '踝靴', '雪靴', '水桶包', '餅乾鞋', '軍靴', '提袋', '尖頭靴', '馬丁靴', '肩背包', '娃娃鞋', '腰包', '低跟鞋', '多功能包', '方包', '雨靴', '方頭鞋', '後背包', '休閒包', '莫卡辛鞋', '劍橋包', '鞋拔', '相機包', 'NG包', '編織包', '球鞋', '腋下包', '樂福鞋', '柏金包', '童鞋', '托特包', '流蘇包', '摺疊鞋', '藤編包', '馬鞍包', '機車靴', '機車包', '工程靴', '慢跑鞋', '帆船鞋', '鍊條包', '拓特包', '短鞋', '跟靴', '蛋糕鞋', '豆豆鞋', '艾瑪包', '情侶鞋', '運動鞋', '瑪麗珍鞋']

# %%
combinedWithProduct = product.merge( combined, on = 'TradesGroupCode', how = 'left')

# %%
combinedWithProduct.describe()
# Out:
#          Unnamed: 0        TsCount            Qty  TotalSalesAmount  \
# count  7.310830e+05  731083.000000  731083.000000     731083.000000
# mean   1.062197e+06       2.920901       3.066633       2419.015292
# std    2.784831e+05       2.221187       2.610242       1578.888564
# min    2.000000e+00       1.000000       1.000000          0.000000
# 25%    8.295345e+05       1.000000       1.000000       1480.000000
# 50%    1.065257e+06       2.000000       2.000000       1943.000000
# 75%    1.294772e+06       4.000000       4.000000       3000.000000
# max    1.542842e+06      33.000000      61.000000      50519.000000
#
#                  low         normal           high  MemberCardLevel
# count  731083.000000  731083.000000  731083.000000    731083.000000
# mean        1.587338       1.068906       0.358080        14.084912
# std         1.860340       0.975659       0.691588         7.352791
# min         0.000000       0.000000       0.000000         0.000000
# 25%         0.000000       0.000000       0.000000        10.000000
# 50%         1.000000       1.000000       0.000000        10.000000
# 75%         2.000000       1.000000       1.000000        20.000000
# max        26.000000      17.000000      12.000000        40.000000

# %%
def AgeCoding(df):
    df.loc[df.Age < 21,'Age']=1
    df.loc[(df.Age > 20) & (df.Age < 31),'Age'] = 2
    df.loc[(df.Age > 30) & (df.Age < 41),'Age'] = 3
    df.loc[(df.Age > 40) & (df.Age < 51),'Age'] = 4
    df.loc[(df.Age > 50) & (df.Age < 61),'Age'] = 5
    df.loc[df.Age > 60,'Age'] = 6
    return df

def GetTag(df, TagList): ##幫每個Tag做Coding
    Dic = {}
    for i in TagList:    
        CodingList = []
        for j in df["SalePageId"]:
            words = j.split("/")
            count = 0
            for k in words:
                if k == i:
                    CodingList.append(1)
                    count += 1
                    break
            if count == 0:
                CodingList.append(0)
        Dic[i] = CodingList
    return Dic

def ModelTraining(df, tags): ##對每個Tag做Training
    score = 0
    training_scores = []
    acc_scores = []
    for i in tags.keys():
        print("這是 " + i + " 的分類器")
        df_c = df.copy()
        df_c[i] = tags[i]
        
        ListFilyer = ["ReviseMemberCardLevel", "Age", "order", "orderSlave", "low", "normal", "high", "SalesLog"]
        ListFilyer.append(i)
        
        train_data, test_data = train_test_split(df_c[ListFilyer], random_state=777, train_size=0.9)
        ListFilyer.pop()
        X_train = train_data[ListFilyer]
        Y_train = train_data[i]
        X_test = test_data[ListFilyer]
        Y_test = test_data[i]
        
        RF_model = RandomForestClassifier(n_estimators = 100)
        RF_model = RF_model.fit(X_train, Y_train)
        train_score = RF_model.score(X_train, Y_train)
        print("Training score :", train_score)

        Y_predict = RF_model.predict(X_test)
        print('準確率 :', accuracy_score(Y_test, Y_predict))

        conf_mat = confusion_matrix(Y_test, Y_predict)
        print(conf_mat)
        if train_score == 1:
            score += 1
        else:
            training_scores = training_scores + [train_score]
            acc_scores = acc_scores + [accuracy_score(Y_test, Y_predict)]
    return score, np.mean(training_scores), np.mean(acc_scores)

def Backtesting(df, tags, forwardtest_data, test_tags): ##對每個Tag做Training
    score = 0
    acc_scores = []
    for i in tags.keys():
        print("這是 " + i + " 的分類器")
        df_c = df.copy()
        forwardtest_data_c = forwardtest_data.copy() # added for forwardtest
        df_c[i] = tags[i]
        forwardtest_data_c[i] = test_tags[i] # added for forwardtest
        
        ListFilyer = ["ReviseMemberCardLevel", "Age", "order", "orderSlave", "low", "normal", "high", "SalesLog"]
        ListFilyer.append(i)
        
        train_data, test_data = train_test_split(df_c[ListFilyer], random_state=777, train_size=0.9)
        forwardtest_data_c = forwardtest_data_c[ListFilyer] # added for forwardtest
        ListFilyer.pop()
        X_train = train_data[ListFilyer]
        Y_train = train_data[i]
        X_test = test_data[ListFilyer]
        Y_test = test_data[i]
        X_forward = forwardtest_data_c[ListFilyer] # added for forwardtest
        Y_forward = forwardtest_data_c[i] # added for forwardtest
        
        RF_model = RandomForestClassifier(n_estimators = 100)
        RF_model = RF_model.fit(X_train, Y_train)
#         train_score = RF_model.score(X_train, Y_train)
#         print("Training score :", train_score)

#         Y_predict = RF_model.predict(X_test)
#         print('準確率 :', accuracy_score(Y_test, Y_predict))
        Y_predict = RF_model.predict(X_forward)  # added for forwardtest
        print('後兩年驗證準確率 :', accuracy_score(Y_forward, Y_predict))  # added for forwardtest
        
        conf_mat = confusion_matrix(Y_forward, Y_predict)
        print(conf_mat)

        acc_scores = acc_scores + [accuracy_score(Y_forward, Y_predict)]
    return  np.mean(acc_scores)

def Predicting(df, tags, predict_data,num): ##對每個Tag做Training
    score = 0
    item = []
    print('第' + str(num+1) +'位會員',predict_data.index.to_list()[num])
    for i in tags.keys():
        df_c = df.copy()
        df_c[i] = tags[i]

        ListFilyer = ["ReviseMemberCardLevel", "Age", "order", "orderSlave", "low", "normal", "high", "SalesLog"]
        ListFilyer.append(i)
        
        train_data, test_data = train_test_split(df_c[ListFilyer], random_state=777, train_size=0.9)
        ListFilyer.pop()
        X_train = train_data[ListFilyer]
        Y_train = train_data[i]

        RF_model = RandomForestClassifier(n_estimators = 100)
        RF_model = RF_model.fit(X_train, Y_train)
        train_score = RF_model.score(X_train, Y_train)

        X_predict = predict_data.copy()
        X_predict = X_predict[ListFilyer].iloc[num].to_numpy().reshape(1,-1)
        Y_predict = RF_model.predict(X_predict)
        if Y_predict == 1 and train_score != 1:
            if train_score > score:
                item = i
                score = train_score
    print('推薦商品 :', item)  
    print("Training score :", score)

# %% [markdown]
# ### Season 1 (1-3月)(2014-2020)

# %%
result = get_season(combinedWithProduct, 2014, 1)
for i in range(2015, 2021,1):
    a = get_season(combinedWithProduct, i, 1)
    result = pd.concat([result, a])
ResultSeason1 = result.dropna()
# Out:
# 2014-01-01 2014-04-01
# 2015-01-01 2015-04-01
# 2016-01-01 2016-04-01
# 2017-01-01 2017-04-01
# 2018-01-01 2018-04-01
# 2019-01-01 2019-04-01
# 2020-01-01 2020-04-01

# %%
ResultSeason1 = AgeCoding(ResultSeason1)
ResultSeason1["SalesLog"] = np.log(ResultSeason1["sales"])
ResultSeason1["ReviseMemberCardLevel"] = ResultSeason1["MemberCardLevel"] / 10
# Out:
# C:\Users\lawre\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\lawre\AppData\Local\Temp/ipykernel_18480/255045546.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ResultSeason1["SalesLog"] = np.log(ResultSeason1["sales"])
# C:\Users\lawre\AppData\Local\Temp/ipykernel_18480/255045546.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ResultSeason1["ReviseMemberCardLevel"] = ResultSeason1["MemberCardLevel"] / 10

# %%
TagDictionary = GetTag(ResultSeason1, ProductTag)

# %%
NumberOfScore1, avg_train_score, avg_acc_score = ModelTraining(ResultSeason1, TagDictionary)
# Out:
# 這是 小白鞋 的分類器
# Training score : 0.9033115157799235
# 準確率 : 0.8145772594752186
# [[2565  198]
#  [ 438  229]]
# 這是 菱格紋包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3430]]
# 這是 鞋用配件 的分類器
# Training score : 0.9875575140950036
# 準確率 : 0.8991253644314868
# [[2828  153]
#  [ 193  256]]
# 這是 短靴 的分類器
# Training score : 0.9468926187544553
# 準確率 : 0.8597667638483965
# [[2797  161]
#  [ 320  152]]
# 這是 拖鞋 的分類器
# Training score : 0.9990603330957164
# 準確率 : 0.9941690962099126
# [[3400    3]
#  [  17   10]]
# 這是 贈品 的分類器
# Training score : 0.9608904153975764
# 準確率 : 0.878134110787172
# [[2410  226]
#  [ 192  602]]
# 這是 跟鞋 的分類器
# Training score : 0.9742077635927678
# 準確率 : 0.9469387755102041
# [[3237   38]
#  [ 144   11]]
# 這是 婚鞋 的分類器
# Training score : 0.9919318255459789
# 準確率 : 0.9836734693877551
# [[3372   10]
#  [  46    2]]
# 這是 膝靴 的分類器
# Training score : 0.9758278789449809
# 準確率 : 0.9472303206997085
# [[3219   46]
#  [ 135   30]]
# 這是 NG鞋 的分類器
# Training score : 0.9991899423238935
# 準確率 : 0.9941690962099126
# [[3408    5]
#  [  15    2]]
# 這是 身體保養 的分類器
# Training score : 0.9699954636770138
# 準確率 : 0.8982507288629737
# [[2994  131]
#  [ 218   87]]
# 這是 鞋墊 的分類器
# Training score : 0.9872334910245609
# 準確率 : 0.9055393586005831
# [[2977  126]
#  [ 198  129]]
# 這是 老爹鞋 的分類器
# Training score : 0.998509493875964
# 準確率 : 0.99533527696793
# [[3413    3]
#  [  13    1]]
# 這是 涼拖鞋 的分類器
# Training score : 0.9980234592703
# 準確率 : 0.9860058309037901
# [[3381   14]
#  [  34    1]]
# 這是 穆勒鞋 的分類器
# Training score : 0.9933575270559264
# 準確率 : 0.9787172011661808
# [[3357   10]
#  [  63    0]]
# 這是 牛津鞋 的分類器
# Training score : 0.9947184239517853
# 準確率 : 0.9903790087463556
# [[3397    8]
#  [  25    0]]
# 這是 日用品 的分類器
# Training score : 0.9847709156891971
# 準確率 : 0.9521865889212828
# [[3247   50]
#  [ 114   19]]
# 這是 厚底鞋 的分類器
# Training score : 0.9983150800336984
# 準確率 : 0.9985422740524781
# [[3425    0]
#  [   5    0]]
# 這是 尖頭鞋 的分類器
# Training score : 0.9534054824703518
# 準確率 : 0.8892128279883382
# [[3013  111]
#  [ 269   37]]
# 這是 帆布鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3430]]
# 這是 涼鞋 的分類器
# Training score : 0.9802345927030005
# 準確率 : 0.9393586005830904
# [[3204   40]
#  [ 168   18]]
# 這是 長靴 的分類器
# Training score : 0.9976994361998575
# 準確率 : 0.9935860058309038
# [[3407    4]
#  [  18    1]]
# 這是 襪靴 的分類器
# Training score : 0.9856133756723479
# 準確率 : 0.9583090379008746
# [[3275   31]
#  [ 112   12]]
# 這是 便鞋 的分類器
# Training score : 0.9863586287343659
# 準確率 : 0.9690962099125364
# [[3315   21]
#  [  85    9]]
# 這是 平底鞋 的分類器
# Training score : 0.971745188257404
# 準確率 : 0.9326530612244898
# [[3188   47]
#  [ 184   11]]
# 這是 小包 的分類器
# Training score : 0.9993519538591148
# 準確率 : 0.997667638483965
# [[3422    2]
#  [   6    0]]
# 這是 皮夾x卡夾x零錢包 的分類器
# Training score : 0.9999027930788672
# 準確率 : 0.9997084548104956
# [[3429    0]
#  [   1    0]]
# 這是 紳士鞋 的分類器
# Training score : 0.9939731708897673
# 準確率 : 0.9871720116618076
# [[3385    3]
#  [  41    1]]
# 這是 服裝衣物 的分類器
# Training score : 0.9969217808307952
# 準確率 : 0.9653061224489796
# [[3307   36]
#  [  83    4]]
# 這是 懶人鞋 的分類器
# Training score : 0.9396345019765407
# 準確率 : 0.8746355685131195
# [[2957   90]
#  [ 340   43]]
# 這是 休閒鞋 的分類器
# Training score : 0.9786468796578316
# 準確率 : 0.9548104956268222
# [[3274   26]
#  [ 129    1]]
# 這是 包鞋 的分類器
# Training score : 0.9764435227788218
# 準確率 : 0.9443148688046648
# [[3233   38]
#  [ 153    6]]
# 這是 飾品配件 的分類器
# Training score : 0.9991251377098049
# 準確率 : 0.9921282798833819
# [[3403    6]
#  [  21    0]]
# 這是 黛妃包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3430]]
# 這是 包用配件 的分類器
# Training score : 0.9995787700084247
# 準確率 : 0.9956268221574344
# [[3415    0]
#  [  15    0]]
# 這是 凱莉包 的分類器
# Training score : 0.9999027930788672
# 準確率 : 0.9979591836734694
# [[3423    1]
#  [   6    0]]
# 這是 高跟鞋 的分類器
# Training score : 0.9906357332642084
# 準確率 : 0.975801749271137
# [[3345   18]
#  [  65    2]]
# 這是 草編鞋 的分類器
# Training score : 0.9971809992871492
# 準確率 : 0.9924198250728863
# [[3404    5]
#  [  21    0]]
# 這是 踝靴 的分類器
# Training score : 0.9890480202190396
# 準確率 : 0.9769679300291545
# [[3349   13]
#  [  66    2]]
# 這是 雪靴 的分類器
# Training score : 0.9667228306655434
# 準確率 : 0.921865889212828
# [[3121   67]
#  [ 201   41]]
# 這是 水桶包 的分類器
# Training score : 0.9988659192534508
# 準確率 : 0.9962099125364432
# [[3416    1]
#  [  12    1]]
# 這是 餅乾鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3430]]
# 這是 軍靴 的分類器
# Training score : 0.9988011146393623
# 準確率 : 0.9982507288629737
# [[3424    2]
#  [   4    0]]
# 這是 提袋 的分類器
# Training score : 0.9995787700084247
# 準確率 : 0.9959183673469387
# [[3415    1]
#  [  13    1]]
# 這是 尖頭靴 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3430]]
# 這是 馬丁靴 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3430]]
# 這是 肩背包 的分類器
# Training score : 0.9996759769295573
# 準確率 : 0.9988338192419826
# [[3426    0]
#  [   4    0]]
# 這是 娃娃鞋 的分類器
# Training score : 0.9903117101937658
# 準確率 : 0.9801749271137026
# [[3362    9]
#  [  59    0]]
# 這是 腰包 的分類器
# Training score : 0.9996435746225131
# 準確率 : 0.9994169096209913
# [[3428    0]
#  [   2    0]]
# 這是 低跟鞋 的分類器
# Training score : 0.9899552848162789
# 準確率 : 0.9807580174927114
# [[3363   21]
#  [  45    1]]
# 這是 多功能包 的分類器
# Training score : 0.9980882638843885
# 準確率 : 0.9924198250728863
# [[3403    5]
#  [  21    1]]
# 這是 方包 的分類器
# Training score : 0.997764240813946
# 準確率 : 0.9892128279883382
# [[3393    7]
#  [  30    0]]
# 這是 雨靴 的分類器
# Training score : 0.9917050093966691
# 準確率 : 0.9795918367346939
# [[3349   16]
#  [  54   11]]
# 這是 方頭鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3430]]
# 這是 後背包 的分類器
# Training score : 0.9975698269716804
# 準確率 : 0.9903790087463556
# [[3395    3]
#  [  30    2]]
# 這是 休閒包 的分類器
# Training score : 0.9998055861577344
# 準確率 : 0.9982507288629737
# [[3424    1]
#  [   5    0]]
# 這是 莫卡辛鞋 的分類器
# Training score : 0.987492709480915
# 準確率 : 0.972594752186589
# [[3334   16]
#  [  78    2]]
# 這是 劍橋包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3430]]
# 這是 鞋拔 的分類器
# Training score : 0.9997731838506901
# 準確率 : 0.9979591836734694
# [[3423    2]
#  [   5    0]]
# 這是 相機包 的分類器
# Training score : 0.9999675976929557
# 準確率 : 1.0
# [[3430]]
# 這是 NG包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3430]]
# 這是 編織包 的分類器
# Training score : 0.9999675976929557
# 準確率 : 1.0
# [[3430]]
# 這是 球鞋 的分類器
# Training score : 0.9865530425766315
# 準確率 : 0.956268221574344
# [[3260   31]
#  [ 119   20]]
# 這是 腋下包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3430]]
# 這是 樂福鞋 的分類器
# Training score : 0.9973430108223705
# 準確率 : 0.9941690962099126
# [[3410    0]
#  [  20    0]]
# 這是 柏金包 的分類器
# Training score : 0.9999351953859115
# 準確率 : 0.9994169096209913
# [[3428    0]
#  [   2    0]]
# 這是 童鞋 的分類器
# Training score : 0.9998379884647787
# 準確率 : 0.9994169096209913
# [[3428    1]
#  [   1    0]]
# 這是 托特包 的分類器
# Training score : 0.9998703907718229
# 準確率 : 1.0
# [[3430]]
# 這是 流蘇包 的分類器
# Training score : 0.9996111723154688
# 準確率 : 0.9991253644314869
# [[3427    0]
#  [   3    0]]
# 這是 摺疊鞋 的分類器
# Training score : 0.9984446892618755
# 準確率 : 0.9965014577259476
# [[3418    4]
#  [   8    0]]
# 這是 藤編包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3430]]
# 這是 馬鞍包 的分類器
# Training score : 0.9999351953859115
# 準確率 : 0.9997084548104956
# [[3429    0]
#  [   1    0]]
# 這是 機車靴 的分類器
# Training score : 0.9995787700084247
# 準確率 : 0.9994169096209913
# [[3428    0]
#  [   2    0]]
# 這是 機車包 的分類器
# Training score : 0.9999027930788672
# 準確率 : 0.9994169096209913
# [[3428    0]
#  [   2    0]]
# 這是 工程靴 的分類器
# Training score : 0.9997083792366016
# 準確率 : 1.0
# [[3430]]
# 這是 慢跑鞋 的分類器
# Training score : 0.9998703907718229
# 準確率 : 0.9994169096209913
# [[3428    0]
#  [   2    0]]
# 這是 帆船鞋 的分類器
# Training score : 0.9995139653943361
# 準確率 : 0.9997084548104956
# [[3429    0]
#  [   1    0]]
# 這是 鍊條包 的分類器
# Training score : 0.9999675976929557
# 準確率 : 1.0
# [[3430]]
# 這是 拓特包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3430]]
# 這是 短鞋 的分類器
# Training score : 0.9999675976929557
# 準確率 : 0.9997084548104956
# [[3429    0]
#  [   1    0]]
# 這是 跟靴 的分類器
# Training score : 0.9999675976929557
# 準確率 : 1.0
# [[3430]]
# 這是 蛋糕鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3430]]
# 這是 豆豆鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3430]]
# 這是 艾瑪包 的分類器
# Training score : 0.9999675976929557
# 準確率 : 1.0
# [[3430]]
# 這是 情侶鞋 的分類器
# Training score : 0.9999351953859115
# 準確率 : 1.0
# [[3430]]
# 這是 運動鞋 的分類器
# Training score : 0.9999351953859115
# 準確率 : 0.9997084548104956
# [[3428    0]
#  [   1    1]]
# 這是 瑪麗珍鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3430]]

# %%
print("Average Training Score: ", avg_train_score)
print("Average Accuracy Score: ", avg_acc_score)

print("Training Score為1的Tag數:", NumberOfScore1)
print("樣本數不足的Tag")
for i in TagDictionary.keys():
    if sum(TagDictionary[i]) <= 3:
        print(i)
# Out:
# Average Training Score:  0.9902046025677029
# Average Accuracy Score:  0.9735179786200194
# Training Score為1的Tag數: 15
# 樣本數不足的Tag
# 菱格紋包
# 帆布鞋
# 黛妃包
# 餅乾鞋
# 尖頭靴
# 馬丁靴
# 方頭鞋
# 劍橋包
# 腋下包
# 藤編包
# 鍊條包
# 拓特包
# 跟靴
# 蛋糕鞋
# 豆豆鞋
# 艾瑪包
# 瑪麗珍鞋

# %% [markdown]
# ## 後兩年驗證Season 1 (1-3月)(2021-2022)

# %%
test = get_season(combinedWithProduct, 2021, 1)
for i in range(2022, 2023,1):
    a = get_season(combinedWithProduct, i, 1)
    test = pd.concat([test, a])
TestSeason1 = test.dropna()

TestSeason1 = AgeCoding(TestSeason1)
TestSeason1["SalesLog"] = np.log(TestSeason1["sales"])
TestSeason1["ReviseMemberCardLevel"] = TestSeason1["MemberCardLevel"] / 10

TestTagDictionary = GetTag(TestSeason1, ProductTag)
# Out:
# 2021-01-01 2021-04-01
# 2022-01-01 2022-04-01

# %%
avg_acc = Backtesting(ResultSeason1, TagDictionary, TestSeason1, TestTagDictionary)
print("Average Accuracy Score: ", avg_acc)
# Out:
# 這是 小白鞋 的分類器
# 後兩年驗證準確率 : 0.8058973901670531
# [[13076  1239]
#  [ 2026   480]]
# 這是 菱格紋包 的分類器
# 後兩年驗證準確率 : 0.9933416562630045
# [[16709     0]
#  [  112     0]]
# 這是 鞋用配件 的分類器
# 後兩年驗證準確率 : 0.8764044943820225
# [[14239  1471]
#  [  608   503]]
# 這是 短靴 的分類器
# 後兩年驗證準確率 : 0.7490042209143333
# [[11848  1370]
#  [ 2852   751]]
# 這是 拖鞋 的分類器
# 後兩年驗證準確率 : 0.9966113786338505
# [[16764    12]
#  [   45     0]]
# 這是 贈品 的分類器
# 後兩年驗證準確率 : 0.8635039533915938
# [[9970  762]
#  [1534 4555]]
# 這是 跟鞋 的分類器
# 後兩年驗證準確率 : 0.9423934367754593
# [[15836   250]
#  [  719    16]]
# 這是 婚鞋 的分類器
# 後兩年驗證準確率 : 0.9756851554604363
# [[16411   130]
#  [  279     1]]
# 這是 膝靴 的分類器
# 後兩年驗證準確率 : 0.9407883003388622
# [[15741   558]
#  [  438    84]]
# 這是 NG鞋 的分類器
# 後兩年驗證準確率 : 0.987634504488437
# [[16601    44]
#  [  164    12]]
# 這是 身體保養 的分類器
# 後兩年驗證準確率 : 0.9282444563343439
# [[15357   743]
#  [  464   257]]
# 這是 鞋墊 的分類器
# 後兩年驗證準確率 : 0.881873848165983
# [[14288   879]
#  [ 1108   546]]
# 這是 老爹鞋 的分類器
# 後兩年驗證準確率 : 0.9710480946436003
# [[16330    39]
#  [  448     4]]
# 這是 涼拖鞋 的分類器
# 後兩年驗證準確率 : 0.9500624219725343
# [[15973    90]
#  [  750     8]]
# 這是 穆勒鞋 的分類器
# 後兩年驗證準確率 : 0.9275905118601748
# [[15594    77]
#  [ 1141     9]]
# 這是 牛津鞋 的分類器
# 後兩年驗證準確率 : 0.9778253373758992
# [[16448    19]
#  [  354     0]]
# 這是 日用品 的分類器
# 後兩年驗證準確率 : 0.9686701147375305
# [[16275   240]
#  [  287    19]]
# 這是 厚底鞋 的分類器
# 後兩年驗證準確率 : 0.9975031210986267
# [[16779     8]
#  [   34     0]]
# 這是 尖頭鞋 的分類器
# 後兩年驗證準確率 : 0.887937696926461
# [[14832   652]
#  [ 1233   104]]
# 這是 帆布鞋 的分類器
# 後兩年驗證準確率 : 0.9437013257237976
# [[15874     0]
#  [  947     0]]
# 這是 涼鞋 的分類器
# 後兩年驗證準確率 : 0.9034540158135663
# [[15139   250]
#  [ 1374    58]]
# 這是 長靴 的分類器
# 後兩年驗證準確率 : 0.9496462754889721
# [[15974    50]
#  [  797     0]]
# 這是 襪靴 的分類器
# 後兩年驗證準確率 : 0.9390048154093098
# [[15726   284]
#  [  742    69]]
# 這是 便鞋 的分類器
# 後兩年驗證準確率 : 0.9861482670471434
# [[16587    83]
#  [  150     1]]
# 這是 平底鞋 的分類器
# 後兩年驗證準確率 : 0.9332976636347423
# [[15667   263]
#  [  859    32]]
# 這是 小包 的分類器
# 後兩年驗證準確率 : 0.9984543130610546
# [[16795     9]
#  [   17     0]]
# 這是 皮夾x卡夾x零錢包 的分類器
# 後兩年驗證準確率 : 0.9771119434040783
# [[16436     1]
#  [  384     0]]
# 這是 紳士鞋 的分類器
# 後兩年驗證準確率 : 0.9357350930384638
# [[15740    53]
#  [ 1028     0]]
# 這是 服裝衣物 的分類器
# 後兩年驗證準確率 : 0.9201593246537066
# [[15391   135]
#  [ 1208    87]]
# 這是 懶人鞋 的分類器
# 後兩年驗證準確率 : 0.9101123595505618
# [[15272   907]
#  [  605    37]]
# 這是 休閒鞋 的分類器
# 後兩年驗證準確率 : 0.9865644135307057
# [[16592    82]
#  [  144     3]]
# 這是 包鞋 的分類器
# 後兩年驗證準確率 : 0.956899114202485
# [[16084   213]
#  [  512    12]]
# 這是 飾品配件 的分類器
# 後兩年驗證準確率 : 0.9841864336246359
# [[16553    51]
#  [  215     2]]
# 這是 黛妃包 的分類器
# 後兩年驗證準確率 : 0.9976220200939302
# [[16781     0]
#  [   40     0]]
# 這是 包用配件 的分類器
# 後兩年驗證準確率 : 0.9821651507044765
# [[16518    10]
#  [  290     3]]
# 這是 凱莉包 的分類器
# 後兩年驗證準確率 : 0.9963141311455919
# [[16759     3]
#  [   59     0]]
# 這是 高跟鞋 的分類器
# 後兩年驗證準確率 : 0.9570774626954403
# [[16092   213]
#  [  509     7]]
# 這是 草編鞋 的分類器
# 後兩年驗證準確率 : 0.9865644135307057
# [[16595    31]
#  [  195     0]]
# 這是 踝靴 的分類器
# 後兩年驗證準確率 : 0.988110100469651
# [[16621    52]
#  [  148     0]]
# 這是 雪靴 的分類器
# 後兩年驗證準確率 : 0.9357945425361156
# [[15719   592]
#  [  488    22]]
# 這是 水桶包 的分類器
# 後兩年驗證準確率 : 0.9958385351643778
# [[16751     4]
#  [   66     0]]
# 這是 餅乾鞋 的分類器
# 後兩年驗證準確率 : 0.9557101242494501
# [[16076     0]
#  [  745     0]]
# 這是 軍靴 的分類器
# 後兩年驗證準確率 : 0.9695618572023066
# [[16309     2]
#  [  510     0]]
# 這是 提袋 的分類器
# 後兩年驗證準確率 : 0.9856726710659295
# [[16580    24]
#  [  217     0]]
# 這是 尖頭靴 的分類器
# 後兩年驗證準確率 : 0.9995838535164377
# [[16814     0]
#  [    7     0]]
# 這是 馬丁靴 的分類器
# 後兩年驗證準確率 : 0.9960763331549849
# [[16755     0]
#  [   66     0]]
# 這是 肩背包 的分類器
# 後兩年驗證準確率 : 0.9980381665774924
# [[16788     2]
#  [   31     0]]
# 這是 娃娃鞋 的分類器
# 後兩年驗證準確率 : 0.9854348730753225
# [[16572    66]
#  [  179     4]]
# 這是 腰包 的分類器
# 後兩年驗證準確率 : 0.9972058736103679
# [[16774    10]
#  [   37     0]]
# 這是 低跟鞋 的分類器
# 後兩年驗證準確率 : 0.9835919386481184
# [[16542    52]
#  [  224     3]]
# 這是 多功能包 的分類器
# 後兩年驗證準確率 : 0.9890018429344272
# [[16632    59]
#  [  126     4]]
# 這是 方包 的分類器
# 後兩年驗證準確率 : 0.9887640449438202
# [[16630    77]
#  [  112     2]]
# 這是 雨靴 的分類器
# 後兩年驗證準確率 : 0.9914987218358005
# [[16678    96]
#  [   47     0]]
# 這是 方頭鞋 的分類器
# 後兩年驗證準確率 : 0.9863860650377504
# [[16592     0]
#  [  229     0]]
# 這是 後背包 的分類器
# 後兩年驗證準確率 : 0.9951251411925569
# [[16739    16]
#  [   66     0]]
# 這是 休閒包 的分類器
# 後兩年驗證準確率 : 0.9995244040187861
# [[16813     4]
#  [    4     0]]
# 這是 莫卡辛鞋 的分類器
# 後兩年驗證準確率 : 0.9925688127935319
# [[16696    69]
#  [   56     0]]
# 這是 劍橋包 的分類器
# 後兩年驗證準確率 : 0.9994649545211343
# [[16812     0]
#  [    9     0]]
# 這是 鞋拔 的分類器
# 後兩年驗證準確率 : 0.9986921110516617
# [[16799     3]
#  [   19     0]]
# 這是 相機包 的分類器
# 後兩年驗證準確率 : 0.997443671600975
# [[16778     4]
#  [   39     0]]
# 這是 NG包 的分類器
# 後兩年驗證準確率 : 0.9995838535164377
# [[16814     0]
#  [    7     0]]
# 這是 編織包 的分類器
# 後兩年驗證準確率 : 0.9996433030140895
# [[16815     0]
#  [    6     0]]
# 這是 球鞋 的分類器
# 後兩年驗證準確率 : 0.9819273527138696
# [[16517   302]
#  [    2     0]]
# 這是 腋下包 的分類器
# 後兩年驗證準確率 : 0.9995838535164377
# [[16814     0]
#  [    7     0]]
# 這是 樂福鞋 的分類器
# 後兩年驗證準確率 : 0.9990488080375721
# [[16805    12]
#  [    4     0]]
# 這是 柏金包 的分類器
# 後兩年驗證準確率 : 0.999762202009393
# [[16817     2]
#  [    2     0]]
# 這是 童鞋 的分類器
# 後兩年驗證準確率 : 0.9901313833898103
# [[16655   119]
#  [   47     0]]
# 這是 托特包 的分類器
# 後兩年驗證準確率 : 0.9998216515070447
# [[16818     0]
#  [    3     0]]
# 這是 流蘇包 的分類器
# 後兩年驗證準確率 : 1.0
# [[16821]]
# 這是 摺疊鞋 的分類器
# 後兩年驗證準確率 : 0.9996433030140895
# [[16815     6]
#  [    0     0]]
# 這是 藤編包 的分類器
# 後兩年驗證準確率 : 1.0
# [[16821]]
# 這是 馬鞍包 的分類器
# 後兩年驗證準確率 : 0.999762202009393
# [[16817     0]
#  [    4     0]]
# 這是 機車靴 的分類器
# 後兩年驗證準確率 : 0.999762202009393
# [[16817     4]
#  [    0     0]]
# 這是 機車包 的分類器
# 後兩年驗證準確率 : 1.0
# [[16821]]
# 這是 工程靴 的分類器
# 後兩年驗證準確率 : 0.9998811010046965
# [[16819     2]
#  [    0     0]]
# 這是 慢跑鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[16821]]
# 這是 帆船鞋 的分類器
# 後兩年驗證準確率 : 0.9998811010046965
# [[16819     2]
#  [    0     0]]
# 這是 鍊條包 的分類器
# 後兩年驗證準確率 : 1.0
# [[16821]]
# 這是 拓特包 的分類器
# 後兩年驗證準確率 : 1.0
# [[16821]]
# 這是 短鞋 的分類器
# 後兩年驗證準確率 : 0.9990488080375721
# [[16805    12]
#  [    4     0]]
# 這是 跟靴 的分類器
# 後兩年驗證準確率 : 1.0
# [[16821]]
# 這是 蛋糕鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[16821]]
# 這是 豆豆鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[16821]]
# 這是 艾瑪包 的分類器
# 後兩年驗證準確率 : 1.0
# [[16821]]
# 這是 情侶鞋 的分類器
# 後兩年驗證準確率 : 0.9995838535164377
# [[16814     7]
#  [    0     0]]
# 這是 運動鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[16821]]
# 這是 瑪麗珍鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[16821]]
# Average Accuracy Score:  0.9719815200894886

# %% [markdown]
# ### 2021 Season 1 預測

# %%
pre = get_season(combinedWithProduct, 2021, 1)
PredictSeason1 = pre.dropna()

PredictSeason1 = AgeCoding(PredictSeason1)
PredictSeason1["SalesLog"] = np.log(PredictSeason1["sales"])
PredictSeason1["ReviseMemberCardLevel"] = PredictSeason1["MemberCardLevel"] / 10
# Out:
# 2021-01-01 2021-04-01

# %%
PredictSeason1.head(3)
# Out:
#                           MemberCardLevel  Gender  Age  order  orderSlave  \
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==               30  Female    3      4          16
# 5aRn4GBf1opsUUHmYIKYUQ==               30  Female    4      9          29
# AlyUS7LorP1qdJwahdia0w==               20  Female    3      1           1
#
#                           low  normal  high  sales  \
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==    4       8     4  21384
# 5aRn4GBf1opsUUHmYIKYUQ==   15      14     0  23090
# AlyUS7LorP1qdJwahdia0w==    0       1     0   1406
#
#                                                 SalePageId     avgSales  \
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==                    短靴/帆布鞋/帆布鞋/贈品/  5346.000000
# 5aRn4GBf1opsUUHmYIKYUQ==  襪靴/襪靴/贈品/贈品/尖頭鞋/方包/服裝衣物/尖頭鞋/小白鞋/  2565.555556
# AlyUS7LorP1qdJwahdia0w==                               涼鞋/  1406.000000
#
#                            SalesLog  ReviseMemberCardLevel
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==   9.970398                    3.0
# 5aRn4GBf1opsUUHmYIKYUQ==  10.047155                    3.0
# AlyUS7LorP1qdJwahdia0w==   7.248504                    2.0

# %%
Predicting(ResultSeason1, TagDictionary, PredictSeason1,0)
# Out:
# 第1位會員 183befUhGBlsXXVQsFUqmQ==
# 推薦商品 : 膝靴
# Training score : 0.9758278789449809

# %%
Predicting(ResultSeason1, TagDictionary, PredictSeason1,1)
# Out:
# 第2位會員 5aRn4GBf1opsUUHmYIKYUQ==
# 推薦商品 : 贈品
# Training score : 0.9610200246257533

# %%
Predicting(ResultSeason1, TagDictionary, PredictSeason1,2)
# Out:
# 第3位會員 AlyUS7LorP1qdJwahdia0w==
# 推薦商品 : []
# Training score : 0

# %% [markdown]
# ### Season 2 (4-6月)(2014-2019)

# %%
result = get_season(combinedWithProduct, 2014, 2)
for i in range(2015, 2020,1):
    a = get_season(combinedWithProduct, i, 2)
    result = pd.concat([result, a])
ResultSeason2 = result.dropna()
# Out:
# 2014-04-01 2014-07-01
# 2015-04-01 2015-07-01
# 2016-04-01 2016-07-01
# 2017-04-01 2017-07-01
# 2018-04-01 2018-07-01
# 2019-04-01 2019-07-01

# %%
ResultSeason2 = AgeCoding(ResultSeason2)
ResultSeason2["SalesLog"] = np.log(ResultSeason2["sales"])
ResultSeason2["ReviseMemberCardLevel"] = ResultSeason2["MemberCardLevel"] / 10

# %%
TagDictionary = GetTag(ResultSeason2, ProductTag)

# %%
NumberOfScore2 , avg_train_score, avg_acc_score= ModelTraining(ResultSeason2, TagDictionary)
# Out:
# 這是 小白鞋 的分類器
# Training score : 0.8714864268815911
# 準確率 : 0.7972582972582972
# [[1913  152]
#  [ 410  297]]
# 這是 菱格紋包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 鞋用配件 的分類器
# Training score : 0.9882112354144111
# 準確率 : 0.9325396825396826
# [[2456   70]
#  [ 117  129]]
# 這是 短靴 的分類器
# Training score : 0.9897349532860179
# 準確率 : 0.9837662337662337
# [[2724   10]
#  [  35    3]]
# 這是 拖鞋 的分類器
# Training score : 0.999759412967641
# 準確率 : 0.9989177489177489
# [[2769    2]
#  [   1    0]]
# 這是 贈品 的分類器
# Training score : 0.975500220538113
# 準確率 : 0.9166666666666666
# [[2076  134]
#  [  97  465]]
# 這是 跟鞋 的分類器
# Training score : 0.964914391114319
# 準確率 : 0.9386724386724387
# [[2597   32]
#  [ 138    5]]
# 這是 婚鞋 的分類器
# Training score : 0.9902963230281888
# 準確率 : 0.9844877344877345
# [[2726    9]
#  [  34    3]]
# 這是 膝靴 的分類器
# Training score : 0.9993985324191026
# 準確率 : 0.9989177489177489
# [[2769    0]
#  [   3    0]]
# 這是 NG鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 身體保養 的分類器
# Training score : 0.991940334415975
# 準確率 : 0.9628427128427128
# [[2643   28]
#  [  75   26]]
# 這是 鞋墊 的分類器
# Training score : 0.9910982798027186
# 準確率 : 0.9498556998556998
# [[2571   41]
#  [  98   62]]
# 這是 老爹鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 涼拖鞋 的分類器
# Training score : 0.9858855607682746
# 準確率 : 0.9491341991341992
# [[2589   60]
#  [  81   42]]
# 這是 穆勒鞋 的分類器
# Training score : 0.9907774970929067
# 準確率 : 0.9823232323232324
# [[2720   14]
#  [  35    3]]
# 這是 牛津鞋 的分類器
# Training score : 0.9943462047395646
# 準確率 : 0.9877344877344877
# [[2738    4]
#  [  30    0]]
# 這是 日用品 的分類器
# Training score : 0.9991980432254701
# 準確率 : 0.9942279942279942
# [[2756    6]
#  [  10    0]]
# 這是 厚底鞋 的分類器
# Training score : 0.9983158907734873
# 準確率 : 0.9967532467532467
# [[2763    1]
#  [   8    0]]
# 這是 尖頭鞋 的分類器
# Training score : 0.9401339267813464
# 準確率 : 0.8906926406926406
# [[2455   67]
#  [ 236   14]]
# 這是 帆布鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 涼鞋 的分類器
# Training score : 0.8225269657965436
# 準確率 : 0.7297979797979798
# [[1748  205]
#  [ 544  275]]
# 這是 長靴 的分類器
# Training score : 0.9995188259352821
# 準確率 : 0.9981962481962482
# [[2766    0]
#  [   5    1]]
# 這是 襪靴 的分類器
# Training score : 0.9995188259352821
# 準確率 : 0.9989177489177489
# [[2769    0]
#  [   3    0]]
# 這是 便鞋 的分類器
# Training score : 0.9828381250250612
# 準確率 : 0.9707792207792207
# [[2684   16]
#  [  65    7]]
# 這是 平底鞋 的分類器
# Training score : 0.9689642728256948
# 準確率 : 0.9411976911976911
# [[2603   32]
#  [ 131    6]]
# 這是 小包 的分類器
# Training score : 0.9969926620955131
# 準確率 : 0.9953102453102453
# [[2759    3]
#  [  10    0]]
# 這是 皮夾x卡夾x零錢包 的分類器
# Training score : 0.9980753037411284
# 準確率 : 0.9985569985569985
# [[2767    2]
#  [   2    1]]
# 這是 紳士鞋 的分類器
# Training score : 0.9983960864509402
# 準確率 : 0.996031746031746
# [[2761    0]
#  [  11    0]]
# 這是 服裝衣物 的分類器
# Training score : 0.9946669874493764
# 準確率 : 0.9660894660894661
# [[2666   29]
#  [  65   12]]
# 這是 懶人鞋 的分類器
# Training score : 0.9246160631941939
# 準確率 : 0.8650793650793651
# [[2375   71]
#  [ 303   23]]
# 這是 休閒鞋 的分類器
# Training score : 0.9706082842134809
# 準確率 : 0.9549062049062049
# [[2646   12]
#  [ 113    1]]
# 這是 包鞋 的分類器
# Training score : 0.9690845663418741
# 準確率 : 0.9451659451659452
# [[2614   26]
#  [ 126    6]]
# 這是 飾品配件 的分類器
# Training score : 0.9997193151289145
# 準確率 : 0.9996392496392497
# [[2771    0]
#  [   1    0]]
# 這是 黛妃包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 包用配件 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 凱莉包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 高跟鞋 的分類器
# Training score : 0.991459160351257
# 準確率 : 0.9787157287157288
# [[2713   15]
#  [  44    0]]
# 這是 草編鞋 的分類器
# Training score : 0.9880107462207787
# 準確率 : 0.9761904761904762
# [[2703   12]
#  [  54    3]]
# 這是 踝靴 的分類器
# Training score : 0.9892537792213
# 準確率 : 0.9808802308802309
# [[2717    8]
#  [  45    2]]
# 這是 雪靴 的分類器
# Training score : 0.9992782389029231
# 準確率 : 0.9978354978354979
# [[2766    0]
#  [   6    0]]
# 這是 水桶包 的分類器
# Training score : 0.9974337383215045
# 準確率 : 0.9945887445887446
# [[2757    4]
#  [  11    0]]
# 這是 餅乾鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 軍靴 的分類器
# Training score : 0.9997995108063675
# 準確率 : 0.9996392496392497
# [[2771    0]
#  [   1    0]]
# 這是 提袋 的分類器
# Training score : 0.999679217290188
# 準確率 : 0.9989177489177489
# [[2769    0]
#  [   3    0]]
# 這是 尖頭靴 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 馬丁靴 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 肩背包 的分類器
# Training score : 0.999759412967641
# 準確率 : 0.9981962481962482
# [[2767    1]
#  [   4    0]]
# 這是 娃娃鞋 的分類器
# Training score : 0.9857652672520951
# 準確率 : 0.9707792207792207
# [[2687   20]
#  [  61    4]]
# 這是 腰包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 低跟鞋 的分類器
# Training score : 0.9833192990897791
# 準確率 : 0.976911976911977
# [[2707    8]
#  [  56    1]]
# 這是 多功能包 的分類器
# Training score : 0.9985163799671197
# 準確率 : 0.9924242424242424
# [[2751    4]
#  [  17    0]]
# 這是 方包 的分類器
# Training score : 0.9979550102249489
# 準確率 : 0.9895382395382395
# [[2742    8]
#  [  21    1]]
# 這是 雨靴 的分類器
# Training score : 0.9922611171257869
# 準確率 : 0.9884559884559885
# [[2739    4]
#  [  28    1]]
# 這是 方頭鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 後背包 的分類器
# Training score : 0.9927422911905048
# 準確率 : 0.983044733044733
# [[2716   18]
#  [  29    9]]
# 這是 休閒包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 莫卡辛鞋 的分類器
# Training score : 0.9884919202854966
# 準確率 : 0.9826839826839827
# [[2724    6]
#  [  42    0]]
# 這是 劍橋包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 鞋拔 的分類器
# Training score : 0.999759412967641
# 準確率 : 0.9985569985569985
# [[2768    2]
#  [   2    0]]
# 這是 相機包 的分類器
# Training score : 0.999919804322547
# 準確率 : 1.0
# [[2772]]
# 這是 NG包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 編織包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 球鞋 的分類器
# Training score : 0.9919002365772485
# 準確率 : 0.974025974025974
# [[2679   23]
#  [  49   21]]
# 這是 腋下包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 樂福鞋 的分類器
# Training score : 0.9960704118048037
# 準確率 : 0.9891774891774892
# [[2741    4]
#  [  26    1]]
# 這是 柏金包 的分類器
# Training score : 0.9999599021612735
# 準確率 : 0.9996392496392497
# [[2771    0]
#  [   1    0]]
# 這是 童鞋 的分類器
# Training score : 0.999759412967641
# 準確率 : 1.0
# [[2772]]
# 這是 托特包 的分類器
# Training score : 0.9998797064838205
# 準確率 : 0.9996392496392497
# [[2771    0]
#  [   1    0]]
# 這是 流蘇包 的分類器
# Training score : 0.9999599021612735
# 準確率 : 1.0
# [[2772]]
# 這是 摺疊鞋 的分類器
# Training score : 0.9962709009984362
# 準確率 : 0.9920634920634921
# [[2749    5]
#  [  17    1]]
# 這是 藤編包 的分類器
# Training score : 0.999919804322547
# 準確率 : 1.0
# [[2772]]
# 這是 馬鞍包 的分類器
# Training score : 0.999839608645094
# 準確率 : 0.9996392496392497
# [[2771    0]
#  [   1    0]]
# 這是 機車靴 的分類器
# Training score : 0.9999599021612735
# 準確率 : 1.0
# [[2772]]
# 這是 機車包 的分類器
# Training score : 0.999759412967641
# 準確率 : 0.9989177489177489
# [[2769    0]
#  [   3    0]]
# 這是 工程靴 的分類器
# Training score : 0.9997193151289145
# 準確率 : 0.9992784992784993
# [[2770    0]
#  [   2    0]]
# 這是 慢跑鞋 的分類器
# Training score : 0.9999599021612735
# 準確率 : 1.0
# [[2772]]
# 這是 帆船鞋 的分類器
# Training score : 0.9997193151289145
# 準確率 : 0.9992784992784993
# [[2770    1]
#  [   1    0]]
# 這是 鍊條包 的分類器
# Training score : 0.999759412967641
# 準確率 : 0.9996392496392497
# [[2771    1]
#  [   0    0]]
# 這是 拓特包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 短鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 跟靴 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 蛋糕鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 豆豆鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 艾瑪包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]
# 這是 情侶鞋 的分類器
# Training score : 1.0
# 準確率 : 0.9996392496392497
# [[2770    0]
#  [   1    1]]
# 這是 運動鞋 的分類器
# Training score : 0.9998797064838205
# 準確率 : 0.9996392496392497
# [[2771    0]
#  [   1    0]]
# 這是 瑪麗珍鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2772]]

# %%
print("Average Training Score: ", avg_train_score)
print("Average Accuracy Score: ", avg_acc_score)

print("Training Score為1的Tag數:", NumberOfScore2)
print("樣本數不足的Tag")
for i in TagDictionary.keys():
    if sum(TagDictionary[i]) <= 3:
        print(i)
# Out:
# Average Training Score:  0.9868103980163211
# Average Accuracy Score:  0.9739154214960666
# Training Score為1的Tag數: 25
# 樣本數不足的Tag
# 菱格紋包
# NG鞋
# 老爹鞋
# 帆布鞋
# 黛妃包
# 包用配件
# 凱莉包
# 餅乾鞋
# 尖頭靴
# 馬丁靴
# 腰包
# 方頭鞋
# 休閒包
# 劍橋包
# 相機包
# NG包
# 腋下包
# 機車靴
# 拓特包
# 短鞋
# 跟靴
# 蛋糕鞋
# 豆豆鞋
# 艾瑪包
# 情侶鞋
# 瑪麗珍鞋

# %% [markdown]
# ## 後兩年驗證Season 2 (4-6月)(2020-2021)

# %%
test = get_season(combinedWithProduct, 2020, 2)
for i in range(2021, 2022, 1):
    a = get_season(combinedWithProduct, i, 2)
    test = pd.concat([test, a])
TestSeason2 = test.dropna()

TestSeason2 = AgeCoding(TestSeason2)
TestSeason2["SalesLog"] = np.log(TestSeason2["sales"])
TestSeason2["ReviseMemberCardLevel"] = TestSeason2["MemberCardLevel"] / 10

TestTagDictionary = GetTag(TestSeason2, ProductTag)

avg_acc = Backtesting(ResultSeason2, TagDictionary, TestSeason2, TestTagDictionary)
print("Average Accuracy Score: ", avg_acc)
# Out:
# 2020-04-01 2020-07-01
# 2021-04-01 2021-07-01
# 這是 小白鞋 的分類器
# 後兩年驗證準確率 : 0.7348167539267015
# [[10354  2322]
#  [ 1730   874]]
# 這是 菱格紋包 的分類器
# 後兩年驗證準確率 : 0.9981020942408377
# [[15251     0]
#  [   29     0]]
# 這是 鞋用配件 的分類器
# 後兩年驗證準確率 : 0.8732329842931937
# [[12854  1154]
#  [  783   489]]
# 這是 短靴 的分類器
# 後兩年驗證準確率 : 0.9662303664921466
# [[14755   194]
#  [  322     9]]
# 這是 拖鞋 的分類器
# 後兩年驗證準確率 : 0.993324607329843
# [[15178     5]
#  [   97     0]]
# 這是 贈品 的分類器
# 後兩年驗證準確率 : 0.8518979057591624
# [[8816  780]
#  [1483 4201]]
# 這是 跟鞋 的分類器
# 後兩年驗證準確率 : 0.9390052356020943
# [[14321   274]
#  [  658    27]]
# 這是 婚鞋 的分類器
# 後兩年驗證準確率 : 0.9762434554973822
# [[14911   200]
#  [  163     6]]
# 這是 膝靴 的分類器
# 後兩年驗證準確率 : 0.9986910994764397
# [[15260     8]
#  [   12     0]]
# 這是 NG鞋 的分類器
# 後兩年驗證準確率 : 0.9892015706806283
# [[15115     0]
#  [  165     0]]
# 這是 身體保養 的分類器
# 後兩年驗證準確率 : 0.9060209424083769
# [[13532   879]
#  [  557   312]]
# 這是 鞋墊 的分類器
# 後兩年驗證準確率 : 0.8710078534031414
# [[12722  1311]
#  [  660   587]]
# 這是 老爹鞋 的分類器
# 後兩年驗證準確率 : 0.9948298429319372
# [[15201     0]
#  [   79     0]]
# 這是 涼拖鞋 的分類器
# 後兩年驗證準確率 : 0.786976439790576
# [[11692   572]
#  [ 2683   333]]
# 這是 穆勒鞋 的分類器
# 後兩年驗證準確率 : 0.9248036649214659
# [[14109   148]
#  [ 1001    22]]
# 這是 牛津鞋 的分類器
# 後兩年驗證準確率 : 0.9856675392670157
# [[15061    32]
#  [  187     0]]
# 這是 日用品 的分類器
# 後兩年驗證準確率 : 0.9492801047120419
# [[14487    74]
#  [  701    18]]
# 這是 厚底鞋 的分類器
# 後兩年驗證準確率 : 0.9994764397905759
# [[15272     1]
#  [    7     0]]
# 這是 尖頭鞋 的分類器
# 後兩年驗證準確率 : 0.868717277486911
# [[13165   596]
#  [ 1410   109]]
# 這是 帆布鞋 的分類器
# 後兩年驗證準確率 : 0.9793193717277487
# [[14964     0]
#  [  316     0]]
# 這是 涼鞋 的分類器
# 後兩年驗證準確率 : 0.6496727748691099
# [[7805 1904]
#  [3449 2122]]
# 這是 長靴 的分類器
# 後兩年驗證準確率 : 0.9993455497382199
# [[15270     1]
#  [    9     0]]
# 這是 襪靴 的分類器
# 後兩年驗證準確率 : 0.9945026178010471
# [[15196    12]
#  [   72     0]]
# 這是 便鞋 的分類器
# 後兩年驗證準確率 : 0.9867146596858639
# [[15076    92]
#  [  111     1]]
# 這是 平底鞋 的分類器
# 後兩年驗證準確率 : 0.9198952879581151
# [[14012   348]
#  [  876    44]]
# 這是 小包 的分類器
# 後兩年驗證準確率 : 0.9958115183246073
# [[15216    23]
#  [   41     0]]
# 這是 皮夾x卡夾x零錢包 的分類器
# 後兩年驗證準確率 : 0.9604057591623036
# [[14673    19]
#  [  586     2]]
# 這是 紳士鞋 的分類器
# 後兩年驗證準確率 : 0.9583115183246074
# [[14643    21]
#  [  616     0]]
# 這是 服裝衣物 的分類器
# 後兩年驗證準確率 : 0.8803664921465969
# [[13156   355]
#  [ 1473   296]]
# 這是 懶人鞋 的分類器
# 後兩年驗證準確率 : 0.9102748691099476
# [[13860   692]
#  [  679    49]]
# 這是 休閒鞋 的分類器
# 後兩年驗證準確率 : 0.9818062827225131
# [[15002   143]
#  [  135     0]]
# 這是 包鞋 的分類器
# 後兩年驗證準確率 : 0.9524869109947643
# [[14530   275]
#  [  451    24]]
# 這是 飾品配件 的分類器
# 後兩年驗證準確率 : 0.9515706806282722
# [[14539     3]
#  [  737     1]]
# 這是 黛妃包 的分類器
# 後兩年驗證準確率 : 0.9871073298429319
# [[15083     0]
#  [  197     0]]
# 這是 包用配件 的分類器
# 後兩年驗證準確率 : 0.9854057591623037
# [[15057     0]
#  [  223     0]]
# 這是 凱莉包 的分類器
# 後兩年驗證準確率 : 0.9922774869109947
# [[15162     0]
#  [  118     0]]
# 這是 高跟鞋 的分類器
# 後兩年驗證準確率 : 0.9674738219895288
# [[14766   142]
#  [  355    17]]
# 這是 草編鞋 的分類器
# 後兩年驗證準確率 : 0.98782722513089
# [[15093    62]
#  [  124     1]]
# 這是 踝靴 的分類器
# 後兩年驗證準確率 : 0.9890052356020942
# [[15112    80]
#  [   88     0]]
# 這是 雪靴 的分類器
# 後兩年驗證準確率 : 0.9992801047120419
# [[15269     1]
#  [   10     0]]
# 這是 水桶包 的分類器
# 後兩年驗證準確率 : 0.9985602094240837
# [[15258    11]
#  [   11     0]]
# 這是 餅乾鞋 的分類器
# 後兩年驗證準確率 : 0.9825261780104712
# [[15013     0]
#  [  267     0]]
# 這是 軍靴 的分類器
# 後兩年驗證準確率 : 0.999738219895288
# [[15276     1]
#  [    3     0]]
# 這是 提袋 的分類器
# 後兩年驗證準確率 : 0.9795157068062827
# [[14966    22]
#  [  291     1]]
# 這是 尖頭靴 的分類器
# 後兩年驗證準確率 : 0.999869109947644
# [[15278     0]
#  [    2     0]]
# 這是 馬丁靴 的分類器
# 後兩年驗證準確率 : 0.9994109947643979
# [[15271     0]
#  [    9     0]]
# 這是 肩背包 的分類器
# 後兩年驗證準確率 : 0.9991492146596859
# [[15267     5]
#  [    8     0]]
# 這是 娃娃鞋 的分類器
# 後兩年驗證準確率 : 0.9838350785340314
# [[15033    62]
#  [  185     0]]
# 這是 腰包 的分類器
# 後兩年驗證準確率 : 0.9939136125654451
# [[15187     0]
#  [   93     0]]
# 這是 低跟鞋 的分類器
# 後兩年驗證準確率 : 0.9793848167539267
# [[14964    61]
#  [  254     1]]
# 這是 多功能包 的分類器
# 後兩年驗證準確率 : 0.9791884816753926
# [[14948    37]
#  [  281    14]]
# 這是 方包 的分類器
# 後兩年驗證準確率 : 0.9872382198952879
# [[15081    50]
#  [  145     4]]
# 這是 雨靴 的分類器
# 後兩年驗證準確率 : 0.9928664921465968
# [[15167    35]
#  [   74     4]]
# 這是 方頭鞋 的分類器
# 後兩年驗證準確率 : 0.9925392670157068
# [[15166     0]
#  [  114     0]]
# 這是 後背包 的分類器
# 後兩年驗證準確率 : 0.9912958115183246
# [[15146   105]
#  [   28     1]]
# 這是 休閒包 的分類器
# 後兩年驗證準確率 : 0.9977094240837696
# [[15245     0]
#  [   35     0]]
# 這是 莫卡辛鞋 的分類器
# 後兩年驗證準確率 : 0.9912303664921466
# [[15146    56]
#  [   78     0]]
# 這是 劍橋包 的分類器
# 後兩年驗證準確率 : 0.993651832460733
# [[15183     0]
#  [   97     0]]
# 這是 鞋拔 的分類器
# 後兩年驗證準確率 : 0.9976439790575916
# [[15244     8]
#  [   28     0]]
# 這是 相機包 的分類器
# 後兩年驗證準確率 : 0.9987565445026177
# [[15261     0]
#  [   19     0]]
# 這是 NG包 的分類器
# 後兩年驗證準確率 : 0.9982329842931937
# [[15253     0]
#  [   27     0]]
# 這是 編織包 的分類器
# 後兩年驗證準確率 : 0.9918848167539267
# [[15156     5]
#  [  119     0]]
# 這是 球鞋 的分類器
# 後兩年驗證準確率 : 0.9794502617801047
# [[14964   279]
#  [   35     2]]
# 這是 腋下包 的分類器
# 後兩年驗證準確率 : 0.999934554973822
# [[15279     0]
#  [    1     0]]
# 這是 樂福鞋 的分類器
# 後兩年驗證準確率 : 0.9979712041884817
# [[15249    21]
#  [   10     0]]
# 這是 柏金包 的分類器
# 後兩年驗證準確率 : 0.999869109947644
# [[15278     0]
#  [    2     0]]
# 這是 童鞋 的分類器
# 後兩年驗證準確率 : 0.9955497382198953
# [[15212     0]
#  [   68     0]]
# 這是 托特包 的分類器
# 後兩年驗證準確率 : 0.999803664921466
# [[15277     1]
#  [    2     0]]
# 這是 流蘇包 的分類器
# 後兩年驗證準確率 : 1.0
# [[15280]]
# 這是 摺疊鞋 的分類器
# 後兩年驗證準確率 : 0.9986256544502617
# [[15259    21]
#  [    0     0]]
# 這是 藤編包 的分類器
# 後兩年驗證準確率 : 1.0
# [[15280]]
# 這是 馬鞍包 的分類器
# 後兩年驗證準確率 : 1.0
# [[15280]]
# 這是 機車靴 的分類器
# 後兩年驗證準確率 : 1.0
# [[15280]]
# 這是 機車包 的分類器
# 後兩年驗證準確率 : 1.0
# [[15280]]
# 這是 工程靴 的分類器
# 後兩年驗證準確率 : 1.0
# [[15280]]
# 這是 慢跑鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[15280]]
# 這是 帆船鞋 的分類器
# 後兩年驗證準確率 : 0.9992801047120419
# [[15269     9]
#  [    2     0]]
# 這是 鍊條包 的分類器
# 後兩年驗證準確率 : 1.0
# [[15280]]
# 這是 拓特包 的分類器
# 後兩年驗證準確率 : 1.0
# [[15280]]
# 這是 短鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[15280]]
# 這是 跟靴 的分類器
# 後兩年驗證準確率 : 1.0
# [[15280]]
# 這是 蛋糕鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[15280]]
# 這是 豆豆鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[15280]]
# 這是 艾瑪包 的分類器
# 後兩年驗證準確率 : 1.0
# [[15280]]
# 這是 情侶鞋 的分類器
# 後兩年驗證準確率 : 0.999934554973822
# [[15279     1]
#  [    0     0]]
# 這是 運動鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[15280]]
# 這是 瑪麗珍鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[15280]]
# Average Accuracy Score:  0.970516639585966

# %% [markdown]
# ### Season 2 預測

# %%
pre = get_season(combinedWithProduct, 2021, 1)
PredictSeason2 = pre.dropna()

PredictSeason2 = AgeCoding(PredictSeason2)
PredictSeason2["SalesLog"] = np.log(PredictSeason2["sales"])
PredictSeason2["ReviseMemberCardLevel"] = PredictSeason2["MemberCardLevel"] / 10
# Out:
# 2021-01-01 2021-04-01

# %%
PredictSeason2.head(3)
# Out:
#                           MemberCardLevel  Gender  Age  order  orderSlave  \
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==               30  Female    3      4          16
# 5aRn4GBf1opsUUHmYIKYUQ==               30  Female    4      9          29
# AlyUS7LorP1qdJwahdia0w==               20  Female    3      1           1
#
#                           low  normal  high  sales  \
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==    4       8     4  21384
# 5aRn4GBf1opsUUHmYIKYUQ==   15      14     0  23090
# AlyUS7LorP1qdJwahdia0w==    0       1     0   1406
#
#                                                 SalePageId     avgSales  \
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==                    短靴/帆布鞋/帆布鞋/贈品/  5346.000000
# 5aRn4GBf1opsUUHmYIKYUQ==  襪靴/襪靴/贈品/贈品/尖頭鞋/方包/服裝衣物/尖頭鞋/小白鞋/  2565.555556
# AlyUS7LorP1qdJwahdia0w==                               涼鞋/  1406.000000
#
#                            SalesLog  ReviseMemberCardLevel
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==   9.970398                    3.0
# 5aRn4GBf1opsUUHmYIKYUQ==  10.047155                    3.0
# AlyUS7LorP1qdJwahdia0w==   7.248504                    2.0

# %%
Predicting(ResultSeason2, TagDictionary, PredictSeason2,0)
Predicting(ResultSeason2, TagDictionary, PredictSeason2,1)
Predicting(ResultSeason2, TagDictionary, PredictSeason2,2)
# Out:
# 第1位會員 183befUhGBlsXXVQsFUqmQ==
# 推薦商品 : 高跟鞋
# Training score : 0.9914992581899835
# 第2位會員 5aRn4GBf1opsUUHmYIKYUQ==
# 推薦商品 : 贈品
# Training score : 0.9755403183768395
# 第3位會員 AlyUS7LorP1qdJwahdia0w==
# 推薦商品 : 涼鞋
# Training score : 0.8225269657965436

# %% [markdown]
# ### Season 3 (7-9月)(2014-2019)

# %%
result = get_season(combinedWithProduct, 2014, 3)
for i in range(2015, 2020,1):
    a = get_season(combinedWithProduct, i, 3)
    result = pd.concat([result, a])
ResultSeason3 = result.dropna()
# Out:
# 2014-07-01 2014-10-01
# 2015-07-01 2015-10-01
# 2016-07-01 2016-10-01
# 2017-07-01 2017-10-01
# 2018-07-01 2018-10-01
# 2019-07-01 2019-10-01

# %%
ResultSeason3 = AgeCoding(ResultSeason3)
ResultSeason3["SalesLog"] = np.log(ResultSeason3["sales"])
ResultSeason3["ReviseMemberCardLevel"] = ResultSeason3["MemberCardLevel"] / 10

# %%
TagDictionary = GetTag(ResultSeason3, ProductTag)

# %%
NumberOfScore1 , avg_train_score, avg_acc_score= ModelTraining(ResultSeason3, TagDictionary)
# Out:
# 這是 小白鞋 的分類器
# Training score : 0.852050231804474
# 準確率 : 0.7464560550830296
# [[1468  242]
#  [ 384  375]]
# 這是 菱格紋包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2469]]
# 這是 鞋用配件 的分類器
# Training score : 0.9889273979385156
# 準確率 : 0.9230457675172135
# [[2190   65]
#  [ 125   89]]
# 這是 短靴 的分類器
# Training score : 0.9867218796417158
# 準確率 : 0.9700283515593358
# [[2394   13]
#  [  61    1]]
# 這是 拖鞋 的分類器
# Training score : 0.9997749471125714
# 準確率 : 0.9995949777237748
# [[2468    0]
#  [   1    0]]
# 這是 贈品 的分類器
# Training score : 0.9843813296124589
# 準確率 : 0.9295261239368166
# [[1366  120]
#  [  54  929]]
# 這是 跟鞋 的分類器
# Training score : 0.9674573524778323
# 準確率 : 0.9335763466990684
# [[2299   26]
#  [ 138    6]]
# 這是 婚鞋 的分類器
# Training score : 0.9910879056578296
# 準確率 : 0.9756986634264885
# [[2407   10]
#  [  50    2]]
# 這是 膝靴 的分類器
# Training score : 0.9987397038304001
# 準確率 : 0.9979748886188741
# [[2464    0]
#  [   5    0]]
# 這是 NG鞋 的分類器
# Training score : 0.9994148624926857
# 準確率 : 0.9902794653705954
# [[2443    9]
#  [  15    2]]
# 這是 身體保養 的分類器
# Training score : 0.9951838682090292
# 準確率 : 0.9538274605103281
# [[2336   38]
#  [  76   19]]
# 這是 鞋墊 的分類器
# Training score : 0.9946437412792006
# 準確率 : 0.9449169704333739
# [[2285   47]
#  [  89   48]]
# 這是 老爹鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2469]]
# 這是 涼拖鞋 的分類器
# Training score : 0.9912229373902867
# 準確率 : 0.9651680842446334
# [[2372   25]
#  [  61   11]]
# 這是 穆勒鞋 的分類器
# Training score : 0.9927532970248009
# 準確率 : 0.9817739975698664
# [[2422   10]
#  [  35    2]]
# 這是 牛津鞋 的分類器
# Training score : 0.994283656659315
# 準確率 : 0.9878493317132442
# [[2439   10]
#  [  20    0]]
# 這是 日用品 的分類器
# Training score : 0.9994148624926857
# 準確率 : 0.9902794653705954
# [[2444    7]
#  [  17    1]]
# 這是 厚底鞋 的分類器
# Training score : 0.9984696403654859
# 準確率 : 0.9963547995139733
# [[2460    2]
#  [   7    0]]
# 這是 尖頭鞋 的分類器
# Training score : 0.9494981320610344
# 準確率 : 0.8825435398946943
# [[2160   64]
#  [ 226   19]]
# 這是 帆布鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2469]]
# 這是 涼鞋 的分類器
# Training score : 0.8979160102624116
# 準確率 : 0.7825030376670717
# [[1669  193]
#  [ 344  263]]
# 這是 長靴 的分類器
# Training score : 0.9999549894225143
# 準確率 : 0.9995949777237748
# [[2468    0]
#  [   1    0]]
# 這是 襪靴 的分類器
# Training score : 0.9990097672953144
# 準確率 : 0.9975698663426489
# [[2463    0]
#  [   6    0]]
# 這是 便鞋 的分類器
# Training score : 0.986856911374173
# 準確率 : 0.9696233292831106
# [[2384   21]
#  [  54   10]]
# 這是 平底鞋 的分類器
# Training score : 0.9785749651168024
# 準確率 : 0.947347104090725
# [[2337   19]
#  [ 111    2]]
# 這是 小包 的分類器
# Training score : 0.9997749471125714
# 準確率 : 0.9987849331713244
# [[2466    1]
#  [   2    0]]
# 這是 皮夾x卡夾x零錢包 的分類器
# Training score : 0.9998199576900572
# 準確率 : 0.9987849331713244
# [[2466    1]
#  [   2    0]]
# 這是 紳士鞋 的分類器
# Training score : 0.9959490480262861
# 準確率 : 0.9939246658566221
# [[2454    2]
#  [  13    0]]
# 這是 服裝衣物 的分類器
# Training score : 0.9969842913084574
# 準確率 : 0.9724584852166869
# [[2401   13]
#  [  55    0]]
# 這是 懶人鞋 的分類器
# Training score : 0.9485529099338345
# 準確率 : 0.884163628999595
# [[2144   77]
#  [ 209   39]]
# 這是 休閒鞋 的分類器
# Training score : 0.9776297429896026
# 準確率 : 0.9534224382341029
# [[2352   17]
#  [  98    2]]
# 這是 包鞋 的分類器
# Training score : 0.9740739073682315
# 準確率 : 0.93681652490887
# [[2308   27]
#  [ 129    5]]
# 這是 飾品配件 的分類器
# Training score : 0.999549894225143
# 準確率 : 0.9947347104090725
# [[2456    2]
#  [  11    0]]
# 這是 黛妃包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2469]]
# 這是 包用配件 的分類器
# Training score : 0.9999549894225143
# 準確率 : 0.9983799108950993
# [[2465    2]
#  [   2    0]]
# 這是 凱莉包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2469]]
# 這是 高跟鞋 的分類器
# Training score : 0.9909978845028582
# 準確率 : 0.9825840421223168
# [[2425    5]
#  [  38    1]]
# 這是 草編鞋 的分類器
# Training score : 0.9880271863888014
# 準確率 : 0.9793438639125152
# [[2410   10]
#  [  41    8]]
# 這是 踝靴 的分類器
# Training score : 0.9927082864473151
# 準確率 : 0.9825840421223168
# [[2425   13]
#  [  30    1]]
# 這是 雪靴 的分類器
# Training score : 0.9987397038304001
# 準確率 : 0.9995949777237748
# [[2468    1]
#  [   0    0]]
# 這是 水桶包 的分類器
# Training score : 0.9987847144078859
# 準確率 : 0.995949777237748
# [[2459    1]
#  [   9    0]]
# 這是 餅乾鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2469]]
# 這是 軍靴 的分類器
# Training score : 0.9999549894225143
# 準確率 : 1.0
# [[2469]]
# 這是 提袋 的分類器
# Training score : 0.9995048836476572
# 準確率 : 0.995949777237748
# [[2459    2]
#  [   8    0]]
# 這是 尖頭靴 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2469]]
# 這是 馬丁靴 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2469]]
# 這是 肩背包 的分類器
# Training score : 0.9998199576900572
# 準確率 : 0.9991899554475496
# [[2467    0]
#  [   2    0]]
# 這是 娃娃鞋 的分類器
# Training score : 0.9896925777557726
# 準確率 : 0.9744835965978129
# [[2405   11]
#  [  52    1]]
# 這是 腰包 的分類器
# Training score : 0.9996849259576001
# 準確率 : 0.9967598217901985
# [[2461    2]
#  [   6    0]]
# 這是 低跟鞋 的分類器
# Training score : 0.9869019219516586
# 準確率 : 0.9724584852166869
# [[2398   10]
#  [  58    3]]
# 這是 多功能包 的分類器
# Training score : 0.9987847144078859
# 準確率 : 0.9963547995139733
# [[2458    0]
#  [   9    2]]
# 這是 方包 的分類器
# Training score : 0.998154566323086
# 準確率 : 0.9927095990279465
# [[2451    5]
#  [  13    0]]
# 這是 雨靴 的分類器
# Training score : 0.9952288787865148
# 準確率 : 0.9910895099230458
# [[2446    1]
#  [  21    1]]
# 這是 方頭鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2469]]
# 這是 後背包 的分類器
# Training score : 0.9960840797587434
# 準確率 : 0.9866342648845686
# [[2435    6]
#  [  27    1]]
# 這是 休閒包 的分類器
# Training score : 0.9999099788450286
# 準確率 : 1.0
# [[2469]]
# 這是 莫卡辛鞋 的分類器
# Training score : 0.9915830220101723
# 準確率 : 0.9858242203321183
# [[2432    3]
#  [  32    2]]
# 這是 劍橋包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2469]]
# 這是 鞋拔 的分類器
# Training score : 0.9986946932529145
# 準確率 : 0.995949777237748
# [[2459    2]
#  [   8    0]]
# 這是 相機包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2469]]
# 這是 NG包 的分類器
# Training score : 0.9999549894225143
# 準確率 : 1.0
# [[2469]]
# 這是 編織包 的分類器
# Training score : 0.9994148624926857
# 準確率 : 0.9995949777237748
# [[2467    0]
#  [   1    1]]
# 這是 球鞋 的分類器
# Training score : 0.9962641220686861
# 準確率 : 0.982989064398542
# [[2405   12]
#  [  30   22]]
# 這是 腋下包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2469]]
# 這是 樂福鞋 的分類器
# Training score : 0.9963541432236576
# 準確率 : 0.9947347104090725
# [[2455    2]
#  [  11    1]]
# 這是 柏金包 的分類器
# Training score : 0.9997749471125714
# 準確率 : 0.9995949777237748
# [[2468    0]
#  [   1    0]]
# 這是 童鞋 的分類器
# Training score : 0.9985596615204573
# 準確率 : 0.9979748886188741
# [[2464    0]
#  [   5    0]]
# 這是 托特包 的分類器
# Training score : 0.9999549894225143
# 準確率 : 1.0
# [[2469]]
# 這是 流蘇包 的分類器
# Training score : 0.9999099788450286
# 準確率 : 0.9995949777237748
# [[2468    0]
#  [   1    0]]
# 這是 摺疊鞋 的分類器
# Training score : 0.9972543547733718
# 準確率 : 0.991494532199271
# [[2448    3]
#  [  18    0]]
# 這是 藤編包 的分類器
# Training score : 0.9999549894225143
# 準確率 : 1.0
# [[2469]]
# 這是 馬鞍包 的分類器
# Training score : 0.9999099788450286
# 準確率 : 0.9995949777237748
# [[2468    0]
#  [   1    0]]
# 這是 機車靴 的分類器
# Training score : 0.9998649682675429
# 準確率 : 0.9995949777237748
# [[2468    1]
#  [   0    0]]
# 這是 機車包 的分類器
# Training score : 0.9995048836476572
# 準確率 : 0.9991899554475496
# [[2467    0]
#  [   2    0]]
# 這是 工程靴 的分類器
# Training score : 0.9997749471125714
# 準確率 : 0.9995949777237748
# [[2468    0]
#  [   1    0]]
# 這是 慢跑鞋 的分類器
# Training score : 0.9999549894225143
# 準確率 : 0.9991899554475496
# [[2467    0]
#  [   2    0]]
# 這是 帆船鞋 的分類器
# Training score : 0.9998199576900572
# 準確率 : 1.0
# [[2469]]
# 這是 鍊條包 的分類器
# Training score : 0.9996849259576001
# 準確率 : 1.0
# [[2469]]
# 這是 拓特包 的分類器
# Training score : 1.0
# 準確率 : 0.9995949777237748
# [[2468    0]
#  [   1    0]]
# 這是 短鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2469]]
# 這是 跟靴 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2469]]
# 這是 蛋糕鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2469]]
# 這是 豆豆鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2469]]
# 這是 艾瑪包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2469]]
# 這是 情侶鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2469]]
# 這是 運動鞋 的分類器
# Training score : 1.0
# 準確率 : 0.9995949777237748
# [[2467    0]
#  [   1    1]]
# 這是 瑪麗珍鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[2469]]

# %%
print("Average Training Score: ", avg_train_score)
print("Average Accuracy Score: ", avg_acc_score)

print("Training Score為1的Tag數:", NumberOfScore1)
print("樣本數不足的Tag")
for i in TagDictionary.keys():
    if sum(TagDictionary[i]) <= 3:
        print(i)
# Out:
# Average Training Score:  0.9901181323065463
# Average Accuracy Score:  0.975569792702235
# Training Score為1的Tag數: 21
# 樣本數不足的Tag
# 菱格紋包
# 老爹鞋
# 帆布鞋
# 黛妃包
# 凱莉包
# 餅乾鞋
# 尖頭靴
# 馬丁靴
# 方頭鞋
# 劍橋包
# 相機包
# NG包
# 腋下包
# 拓特包
# 短鞋
# 跟靴
# 蛋糕鞋
# 豆豆鞋
# 艾瑪包
# 情侶鞋
# 瑪麗珍鞋

# %% [markdown]
# ## 後兩年驗證Season 3 (7-9月)(2020-2021)

# %%
test = get_season(combinedWithProduct, 2020, 3)
for i in range(2021, 2022, 1):
    a = get_season(combinedWithProduct, i, 3)
    test = pd.concat([test, a])
TestSeason3 = test.dropna()

TestSeason3 = AgeCoding(TestSeason3)
TestSeason3["SalesLog"] = np.log(TestSeason3["sales"])
TestSeason3["ReviseMemberCardLevel"] = TestSeason3["MemberCardLevel"] / 10

TestTagDictionary = GetTag(TestSeason3, ProductTag)

avg_acc = Backtesting(ResultSeason3, TagDictionary, TestSeason3, TestTagDictionary)
print("Average Accuracy Score: ", avg_acc)
# Out:
# 2020-07-01 2020-10-01
# 2021-07-01 2021-10-01
# 這是 小白鞋 的分類器
# 後兩年驗證準確率 : 0.7229750827452694
# [[10652  2900]
#  [ 1536   925]]
# 這是 菱格紋包 的分類器
# 後兩年驗證準確率 : 0.996065696621495
# [[15950     0]
#  [   63     0]]
# 這是 鞋用配件 的分類器
# 後兩年驗證準確率 : 0.9037656903765691
# [[14185   751]
#  [  790   287]]
# 這是 短靴 的分類器
# 後兩年驗證準確率 : 0.9516642727783676
# [[15230   184]
#  [  590     9]]
# 這是 拖鞋 的分類器
# 後兩年驗證準確率 : 0.9966901892212577
# [[15960     5]
#  [   48     0]]
# 這是 贈品 的分類器
# 後兩年驗證準確率 : 0.8511834134765504
# [[9451 1725]
#  [ 658 4179]]
# 這是 跟鞋 的分類器
# 後兩年驗證準確率 : 0.9377380878036595
# [[14988   230]
#  [  767    28]]
# 這是 婚鞋 的分類器
# 後兩年驗證準確率 : 0.9811403234871667
# [[15703   104]
#  [  198     8]]
# 這是 膝靴 的分類器
# 後兩年驗證準確率 : 0.9955036532817086
# [[15941     5]
#  [   67     0]]
# 這是 NG鞋 的分類器
# 後兩年驗證準確率 : 0.9636545306938112
# [[15363    77]
#  [  505    68]]
# 這是 身體保養 的分類器
# 後兩年驗證準確率 : 0.9426091300818086
# [[14957   226]
#  [  693   137]]
# 這是 鞋墊 的分類器
# 後兩年驗證準確率 : 0.9084493848747892
# [[14235   605]
#  [  861   312]]
# 這是 老爹鞋 的分類器
# 後兩年驗證準確率 : 0.9910697558233935
# [[15870     0]
#  [  143     0]]
# 這是 涼拖鞋 的分類器
# 後兩年驗證準確率 : 0.7828639230625117
# [[12502   145]
#  [ 3332    34]]
# 這是 穆勒鞋 的分類器
# 後兩年驗證準確率 : 0.9373009429838256
# [[15000   122]
#  [  882     9]]
# 這是 牛津鞋 的分類器
# 後兩年驗證準確率 : 0.9782052082682821
# [[15663    18]
#  [  331     1]]
# 這是 日用品 的分類器
# 後兩年驗證準確率 : 0.9711484418909636
# [[15530    63]
#  [  399    21]]
# 這是 厚底鞋 的分類器
# 後兩年驗證準確率 : 0.9979391744207831
# [[15980     7]
#  [   26     0]]
# 這是 尖頭鞋 的分類器
# 後兩年驗證準確率 : 0.8716667707487666
# [[13784   647]
#  [ 1408   174]]
# 這是 帆布鞋 的分類器
# 後兩年驗證準確率 : 0.986760756885031
# [[15801     0]
#  [  212     0]]
# 這是 涼鞋 的分類器
# 後兩年驗證準確率 : 0.6870043089989384
# [[8740 1514]
#  [3498 2261]]
# 這是 長靴 的分類器
# 後兩年驗證準確率 : 0.998126522200712
# [[15983     2]
#  [   28     0]]
# 這是 襪靴 的分類器
# 後兩年驗證準確率 : 0.9878848435646037
# [[15818    12]
#  [  182     1]]
# 這是 便鞋 的分類器
# 後兩年驗證準確率 : 0.9858864672453631
# [[15786    77]
#  [  149     1]]
# 這是 平底鞋 的分類器
# 後兩年驗證準確率 : 0.9284955973271717
# [[14839   212]
#  [  933    29]]
# 這是 小包 的分類器
# 後兩年驗證準確率 : 0.9977518266408543
# [[15977     3]
#  [   33     0]]
# 這是 皮夾x卡夾x零錢包 的分類器
# 後兩年驗證準確率 : 0.9773309186286142
# [[15650     5]
#  [  358     0]]
# 這是 紳士鞋 的分類器
# 後兩年驗證準確率 : 0.9460438393805033
# [[15148    10]
#  [  854     1]]
# 這是 服裝衣物 的分類器
# 後兩年驗證準確率 : 0.9166926871916568
# [[14637    92]
#  [ 1242    42]]
# 這是 懶人鞋 的分類器
# 後兩年驗證準確率 : 0.9178792231312058
# [[14655   535]
#  [  780    43]]
# 這是 休閒鞋 的分類器
# 後兩年驗證準確率 : 0.9825142072066446
# [[15731    96]
#  [  184     2]]
# 這是 包鞋 的分類器
# 後兩年驗證準確率 : 0.9557234746768251
# [[15281   193]
#  [  516    23]]
# 這是 飾品配件 的分類器
# 後兩年驗證準確率 : 0.9617810528945232
# [[15394    32]
#  [  580     7]]
# 這是 黛妃包 的分類器
# 後兩年驗證準確率 : 0.9933803784425155
# [[15907     0]
#  [  106     0]]
# 這是 包用配件 的分類器
# 後兩年驗證準確率 : 0.9785799038281396
# [[15670     1]
#  [  342     0]]
# 這是 凱莉包 的分類器
# 後兩年驗證準確率 : 0.9907575095235122
# [[15865     0]
#  [  148     0]]
# 這是 高跟鞋 的分類器
# 後兩年驗證準確率 : 0.9718353837507026
# [[15555   108]
#  [  343     7]]
# 這是 草編鞋 的分類器
# 後兩年驗證準確率 : 0.9825766564666208
# [[15732    98]
#  [  181     2]]
# 這是 踝靴 的分類器
# 後兩年驗證準確率 : 0.9889464809842003
# [[15835    29]
#  [  148     1]]
# 這是 雪靴 的分類器
# 後兩年驗證準確率 : 0.9948167114219697
# [[15930    18]
#  [   65     0]]
# 這是 水桶包 的分類器
# 後兩年驗證準確率 : 0.9987510148004746
# [[15993    12]
#  [    8     0]]
# 這是 餅乾鞋 的分類器
# 後兩年驗證準確率 : 0.9841378879660276
# [[15759     0]
#  [  254     0]]
# 這是 軍靴 的分類器
# 後兩年驗證準確率 : 0.9978142759008306
# [[15978     0]
#  [   35     0]]
# 這是 提袋 的分類器
# 後兩年驗證準確率 : 0.9777056141884719
# [[15656    12]
#  [  345     0]]
# 這是 尖頭靴 的分類器
# 後兩年驗證準確率 : 0.9997502029600949
# [[16009     0]
#  [    4     0]]
# 這是 馬丁靴 的分類器
# 後兩年驗證準確率 : 0.9990008118403797
# [[15997     0]
#  [   16     0]]
# 這是 肩背包 的分類器
# 後兩年驗證準確率 : 1.0
# [[16013]]
# 這是 娃娃鞋 的分類器
# 後兩年驗證準確率 : 0.9861362642852682
# [[15791    65]
#  [  157     0]]
# 這是 腰包 的分類器
# 後兩年驗證準確率 : 0.9940048710422782
# [[15917     7]
#  [   89     0]]
# 這是 低跟鞋 的分類器
# 後兩年驗證準確率 : 0.9827640042465496
# [[15735    50]
#  [  226     2]]
# 這是 多功能包 的分類器
# 後兩年驗證準確率 : 0.982826453506526
# [[15734    27]
#  [  248     4]]
# 這是 方包 的分類器
# 後兩年驗證準確率 : 0.987010553924936
# [[15805    24]
#  [  184     0]]
# 這是 雨靴 的分類器
# 後兩年驗證準確率 : 0.992818335102729
# [[15898    24]
#  [   91     0]]
# 這是 方頭鞋 的分類器
# 後兩年驗證準確率 : 0.9901954661837257
# [[15856     0]
#  [  157     0]]
# 這是 後背包 的分類器
# 後兩年驗證準確率 : 0.9977518266408543
# [[15977    25]
#  [   11     0]]
# 這是 休閒包 的分類器
# 後兩年驗證準確率 : 0.9954412040217323
# [[15940     0]
#  [   73     0]]
# 這是 莫卡辛鞋 的分類器
# 後兩年驗證準確率 : 0.9906326110035596
# [[15861    48]
#  [  102     2]]
# 這是 劍橋包 的分類器
# 後兩年驗證準確率 : 0.9995628551801661
# [[16006     0]
#  [    7     0]]
# 這是 鞋拔 的分類器
# 後兩年驗證準確率 : 0.9972522325610441
# [[15969    20]
#  [   24     0]]
# 這是 相機包 的分類器
# 後兩年驗證準確率 : 0.9988134640604509
# [[15994     0]
#  [   19     0]]
# 這是 NG包 的分類器
# 後兩年驗證準確率 : 0.9969399862611628
# [[15964     0]
#  [   49     0]]
# 這是 編織包 的分類器
# 後兩年驗證準確率 : 0.9959407981015425
# [[15947     8]
#  [   57     1]]
# 這是 球鞋 的分類器
# 後兩年驗證準確率 : 0.9783925560482108
# [[15654   259]
#  [   87    13]]
# 這是 腋下包 的分類器
# 後兩年驗證準確率 : 0.9986885655404983
# [[15992     0]
#  [   21     0]]
# 這是 樂福鞋 的分類器
# 後兩年驗證準確率 : 0.9977518266408543
# [[15977    21]
#  [   15     0]]
# 這是 柏金包 的分類器
# 後兩年驗證準確率 : 0.9965652907013052
# [[15958     0]
#  [   55     0]]
# 這是 童鞋 的分類器
# 後兩年驗證準確率 : 0.9957534503216137
# [[15945    17]
#  [   51     0]]
# 這是 托特包 的分類器
# 後兩年驗證準確率 : 0.9994379566602136
# [[16004     0]
#  [    9     0]]
# 這是 流蘇包 的分類器
# 後兩年驗證準確率 : 1.0
# [[16013]]
# 這是 摺疊鞋 的分類器
# 後兩年驗證準確率 : 0.9991257103603323
# [[15999    14]
#  [    0     0]]
# 這是 藤編包 的分類器
# 後兩年驗證準確率 : 0.9999375507400238
# [[16012     1]
#  [    0     0]]
# 這是 馬鞍包 的分類器
# 後兩年驗證準確率 : 0.9980640729407356
# [[15982     1]
#  [   30     0]]
# 這是 機車靴 的分類器
# 後兩年驗證準確率 : 0.9998751014800474
# [[16011     1]
#  [    1     0]]
# 這是 機車包 的分類器
# 後兩年驗證準確率 : 0.9998126522200712
# [[16010     3]
#  [    0     0]]
# 這是 工程靴 的分類器
# 後兩年驗證準確率 : 1.0
# [[16013]]
# 這是 慢跑鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[16013]]
# 這是 帆船鞋 的分類器
# 後兩年驗證準確率 : 0.9999375507400238
# [[16012     0]
#  [    1     0]]
# 這是 鍊條包 的分類器
# 後兩年驗證準確率 : 1.0
# [[16013]]
# 這是 拓特包 的分類器
# 後兩年驗證準確率 : 0.9998126522200712
# [[16010     0]
#  [    3     0]]
# 這是 短鞋 的分類器
# 後兩年驗證準確率 : 0.9995628551801661
# [[16006     0]
#  [    7     0]]
# 這是 跟靴 的分類器
# 後兩年驗證準確率 : 1.0
# [[16013]]
# 這是 蛋糕鞋 的分類器
# 後兩年驗證準確率 : 0.9998751014800474
# [[16011     1]
#  [    1     0]]
# 這是 豆豆鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[16013]]
# 這是 艾瑪包 的分類器
# 後兩年驗證準確率 : 1.0
# [[16013]]
# 這是 情侶鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[16013]]
# 這是 運動鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[16013]]
# 這是 瑪麗珍鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[16013]]
# Average Accuracy Score:  0.9726465063228081

# %% [markdown]
# ### Season 3 預測

# %%
pre = get_season(combinedWithProduct, 2021, 1)
PredictSeason3 = pre.dropna()

PredictSeason3 = AgeCoding(PredictSeason3)
PredictSeason3["SalesLog"] = np.log(PredictSeason3["sales"])
PredictSeason3["ReviseMemberCardLevel"] = PredictSeason3["MemberCardLevel"] / 10
# Out:
# 2021-01-01 2021-04-01

# %%
PredictSeason3.head(3)
# Out:
#                           MemberCardLevel  Gender  Age  order  orderSlave  \
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==               30  Female    3      4          16
# 5aRn4GBf1opsUUHmYIKYUQ==               30  Female    4      9          29
# AlyUS7LorP1qdJwahdia0w==               20  Female    3      1           1
#
#                           low  normal  high  sales  \
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==    4       8     4  21384
# 5aRn4GBf1opsUUHmYIKYUQ==   15      14     0  23090
# AlyUS7LorP1qdJwahdia0w==    0       1     0   1406
#
#                                                 SalePageId     avgSales  \
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==                    短靴/帆布鞋/帆布鞋/贈品/  5346.000000
# 5aRn4GBf1opsUUHmYIKYUQ==  襪靴/襪靴/贈品/贈品/尖頭鞋/方包/服裝衣物/尖頭鞋/小白鞋/  2565.555556
# AlyUS7LorP1qdJwahdia0w==                               涼鞋/  1406.000000
#
#                            SalesLog  ReviseMemberCardLevel
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==   9.970398                    3.0
# 5aRn4GBf1opsUUHmYIKYUQ==  10.047155                    3.0
# AlyUS7LorP1qdJwahdia0w==   7.248504                    2.0

# %%
Predicting(ResultSeason3, TagDictionary, PredictSeason3,0)
Predicting(ResultSeason3, TagDictionary, PredictSeason3,1)
Predicting(ResultSeason3, TagDictionary, PredictSeason3,2)
# Out:
# 第1位會員 183befUhGBlsXXVQsFUqmQ==
# 推薦商品 : 膝靴
# Training score : 0.9987397038304001
# 第2位會員 5aRn4GBf1opsUUHmYIKYUQ==
# 推薦商品 : 贈品
# Training score : 0.9843813296124589
# 第3位會員 AlyUS7LorP1qdJwahdia0w==
# 推薦商品 : []
# Training score : 0

# %% [markdown]
# ### Season 4 (10-12月)(2014-2019)

# %%
result = get_season(combinedWithProduct, 2013, 4)
for i in range(2014, 2020,1):
    a = get_season(combinedWithProduct, i, 4)
    result = pd.concat([result, a])
ResultSeason4 = result.dropna()
# Out:
# 2013-10-01 2014-01-01
# 2014-10-01 2015-01-01
# 2015-10-01 2016-01-01
# 2016-10-01 2017-01-01
# 2017-10-01 2018-01-01
# 2018-10-01 2019-01-01
# 2019-10-01 2020-01-01

# %%
ResultSeason4 = AgeCoding(ResultSeason4)
ResultSeason4["SalesLog"] = np.log(ResultSeason4["sales"])
ResultSeason4["ReviseMemberCardLevel"] = ResultSeason4["MemberCardLevel"] / 10

# %%
TagDictionary = GetTag(ResultSeason4, ProductTag)

# %%
NumberOfScore1, avg_train_score, avg_acc_score = ModelTraining(ResultSeason4, TagDictionary)
# Out:
# 這是 小白鞋 的分類器
# Training score : 0.8983190874138095
# 準確率 : 0.7941092364884187
# [[2577  249]
#  [ 471  200]]
# 這是 菱格紋包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3497]]
# 這是 鞋用配件 的分類器
# Training score : 0.9861142003749483
# 準確率 : 0.9044895624821275
# [[2986  153]
#  [ 181  177]]
# 這是 短靴 的分類器
# Training score : 0.9174795843792698
# 準確率 : 0.7929653989133543
# [[2468  308]
#  [ 416  305]]
# 這是 拖鞋 的分類器
# Training score : 0.9996186965778018
# 準確率 : 0.996854446668573
# [[3486    1]
#  [  10    0]]
# 這是 贈品 的分類器
# Training score : 0.9438848463664962
# 準確率 : 0.8484415213039749
# [[1936  354]
#  [ 176 1031]]
# 這是 跟鞋 的分類器
# Training score : 0.9699088049315243
# 準確率 : 0.9302259079210752
# [[3247   45]
#  [ 199    6]]
# 這是 婚鞋 的分類器
# Training score : 0.9901496615932128
# 準確率 : 0.9814126394052045
# [[3432   13]
#  [  52    0]]
# 這是 膝靴 的分類器
# Training score : 0.975882558545963
# 準確率 : 0.9348012582213325
# [[3095  110]
#  [ 118  174]]
# 這是 NG鞋 的分類器
# Training score : 0.9997140224333514
# 準確率 : 0.9945667715184444
# [[3477    3]
#  [  16    1]]
# 這是 身體保養 的分類器
# Training score : 0.9625051634838423
# 準確率 : 0.8867600800686303
# [[2991  122]
#  [ 274  110]]
# 這是 鞋墊 的分類器
# Training score : 0.9814750087382035
# 準確率 : 0.9044895624821275
# [[3010  122]
#  [ 212  153]]
# 這是 老爹鞋 的分類器
# Training score : 0.9989196403037717
# 準確率 : 0.9948527309122105
# [[3479    3]
#  [  15    0]]
# 這是 涼拖鞋 的分類器
# Training score : 0.9981570334593753
# 準確率 : 0.9917071775807835
# [[3467    4]
#  [  25    1]]
# 這是 穆勒鞋 的分類器
# Training score : 0.9937720441040958
# 準確率 : 0.9805547612239062
# [[3428    9]
#  [  59    1]]
# 這是 牛津鞋 的分類器
# Training score : 0.9954879095039878
# 準確率 : 0.9919931369745496
# [[3468    9]
#  [  19    1]]
# 這是 日用品 的分類器
# Training score : 0.9993962695815195
# 準確率 : 0.9868458678867601
# [[3448   11]
#  [  35    3]]
# 這是 厚底鞋 的分類器
# Training score : 0.999650471862985
# 準確率 : 0.9985702030311696
# [[3492    1]
#  [   4    0]]
# 這是 尖頭鞋 的分類器
# Training score : 0.9617107813542627
# 準確率 : 0.9047755218758936
# [[3147   66]
#  [ 267   17]]
# 這是 帆布鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3497]]
# 這是 涼鞋 的分類器
# Training score : 0.988815099615519
# 準確率 : 0.9585358879039176
# [[3325   23]
#  [ 122   27]]
# 這是 長靴 的分類器
# Training score : 0.9972673254742461
# 準確率 : 0.9879897054618244
# [[3452    7]
#  [  35    3]]
# 這是 襪靴 的分類器
# Training score : 0.9741984684312541
# 準確率 : 0.9345152988275665
# [[3235   58]
#  [ 171   33]]
# 這是 便鞋 的分類器
# Training score : 0.9876711893489244
# 準確率 : 0.9688304260794968
# [[3380   21]
#  [  88    8]]
# 這是 平底鞋 的分類器
# Training score : 0.9740395920053383
# 準確率 : 0.9373748927652273
# [[3271   56]
#  [ 163    7]]
# 這是 小包 的分類器
# Training score : 0.9997457977185346
# 準確率 : 0.9951386903059766
# [[3478    0]
#  [  17    2]]
# 這是 皮夾x卡夾x零錢包 的分類器
# Training score : 0.9998728988592672
# 準確率 : 0.9977123248498713
# [[3488    0]
#  [   8    1]]
# 這是 紳士鞋 的分類器
# Training score : 0.9954243589336215
# 準確率 : 0.9845581927366314
# [[3442   11]
#  [  43    1]]
# 這是 服裝衣物 的分類器
# Training score : 0.9979663817482762
# 準確率 : 0.9688304260794968
# [[3374   30]
#  [  79   14]]
# 這是 懶人鞋 的分類器
# Training score : 0.9568173874360523
# 準確率 : 0.8890477552187589
# [[3071   94]
#  [ 294   38]]
# 這是 休閒鞋 的分類器
# Training score : 0.9894506053191827
# 準確率 : 0.9754074921361167
# [[3409   21]
#  [  65    2]]
# 這是 包鞋 的分類器
# Training score : 0.9748339741349179
# 準確率 : 0.9456677151844438
# [[3292   32]
#  [ 158   15]]
# 這是 飾品配件 的分類器
# Training score : 0.9989196403037717
# 準確率 : 0.9905633400057192
# [[3461    9]
#  [  24    3]]
# 這是 黛妃包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3497]]
# 這是 包用配件 的分類器
# Training score : 0.9998093482889009
# 準確率 : 0.9928510151558478
# [[3470    5]
#  [  20    2]]
# 這是 凱莉包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3497]]
# 這是 高跟鞋 的分類器
# Training score : 0.9894823806043659
# 準確率 : 0.9771232484987132
# [[3416   11]
#  [  69    1]]
# 這是 草編鞋 的分類器
# Training score : 0.9968860220520479
# 準確率 : 0.9919931369745496
# [[3467    5]
#  [  23    2]]
# 這是 踝靴 的分類器
# Training score : 0.9843030091195069
# 準確率 : 0.9653989133543037
# [[3376   30]
#  [  91    0]]
# 這是 雪靴 的分類器
# Training score : 0.9605986463728512
# 準確率 : 0.9150700600514727
# [[3112   81]
#  [ 216   88]]
# 這是 水桶包 的分類器
# Training score : 0.9982205840297417
# 準確率 : 0.9948527309122105
# [[3479    5]
#  [  13    0]]
# 這是 餅乾鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3497]]
# 這是 軍靴 的分類器
# Training score : 0.998284134600108
# 準確率 : 0.9951386903059766
# [[3480    4]
#  [  13    0]]
# 這是 提袋 的分類器
# Training score : 0.9955832353595373
# 準確率 : 0.9879897054618244
# [[3451    8]
#  [  34    4]]
# 這是 尖頭靴 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3497]]
# 這是 馬丁靴 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3497]]
# 這是 肩背包 的分類器
# Training score : 0.9998093482889009
# 準確率 : 0.9991421218187018
# [[3494    0]
#  [   3    0]]
# 這是 娃娃鞋 的分類器
# Training score : 0.9903720885894951
# 準確率 : 0.973119816985988
# [[3401   15]
#  [  79    2]]
# 這是 腰包 的分類器
# Training score : 0.998951415588955
# 準確率 : 0.9951386903059766
# [[3479    1]
#  [  16    1]]
# 這是 低跟鞋 的分類器
# Training score : 0.9909122684376093
# 準確率 : 0.9796968830426079
# [[3424   10]
#  [  61    2]]
# 這是 多功能包 的分類器
# Training score : 0.9988560897334053
# 準確率 : 0.9962825278810409
# [[3484    1]
#  [  12    0]]
# 這是 方包 的分類器
# Training score : 0.9988560897334053
# 準確率 : 0.9931369745496139
# [[3473    4]
#  [  20    0]]
# 這是 雨靴 的分類器
# Training score : 0.9920244034190207
# 準確率 : 0.9822705175865027
# [[3421   14]
#  [  48   14]]
# 這是 方頭鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3497]]
# 這是 後背包 的分類器
# Training score : 0.9984112357408408
# 準確率 : 0.9925650557620818
# [[3471    9]
#  [  17    0]]
# 這是 休閒包 的分類器
# Training score : 0.9998411235740841
# 準確率 : 0.9974263654561052
# [[3488    0]
#  [   9    0]]
# 這是 莫卡辛鞋 的分類器
# Training score : 0.9913571224301738
# 準確率 : 0.9814126394052045
# [[3432   14]
#  [  51    0]]
# 這是 劍橋包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3497]]
# 這是 鞋拔 的分類器
# Training score : 0.9998728988592672
# 準確率 : 0.9982842436374035
# [[3491    1]
#  [   5    0]]
# 這是 相機包 的分類器
# Training score : 0.9999364494296337
# 準確率 : 1.0
# [[3497]]
# 這是 NG包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3497]]
# 這是 編織包 的分類器
# Training score : 0.9998411235740841
# 準確率 : 0.9991421218187018
# [[3494    0]
#  [   3    0]]
# 這是 球鞋 的分類器
# Training score : 0.9940897969559277
# 準確率 : 0.9762653703174149
# [[3390   23]
#  [  60   24]]
# 這是 腋下包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3497]]
# 這是 樂福鞋 的分類器
# Training score : 0.9980934828890089
# 準確率 : 0.9928510151558478
# [[3472    4]
#  [  21    0]]
# 這是 柏金包 的分類器
# Training score : 0.9999364494296337
# 準確率 : 1.0
# [[3497]]
# 這是 童鞋 的分類器
# Training score : 0.9999046741444505
# 準確率 : 0.9985702030311696
# [[3492    0]
#  [   5    0]]
# 這是 托特包 的分類器
# Training score : 1.0
# 準確率 : 0.9997140406062339
# [[3496    1]
#  [   0    0]]
# 這是 流蘇包 的分類器
# Training score : 0.9998093482889009
# 準確率 : 0.9997140406062339
# [[3496    0]
#  [   1    0]]
# 這是 摺疊鞋 的分類器
# Training score : 0.9983159098852912
# 準確率 : 0.9954246496997426
# [[3481    1]
#  [  15    0]]
# 這是 藤編包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3497]]
# 這是 馬鞍包 的分類器
# Training score : 0.9999046741444505
# 準確率 : 0.9994280812124678
# [[3495    0]
#  [   2    0]]
# 這是 機車靴 的分類器
# Training score : 0.9984112357408408
# 準確率 : 0.9957106090935087
# [[3482    4]
#  [  11    0]]
# 這是 機車包 的分類器
# Training score : 0.999491595437069
# 準確率 : 0.9985702030311696
# [[3492    0]
#  [   5    0]]
# 這是 工程靴 的分類器
# Training score : 0.9998411235740841
# 準確率 : 1.0
# [[3497]]
# 這是 慢跑鞋 的分類器
# Training score : 0.9998411235740841
# 準確率 : 1.0
# [[3497]]
# 這是 帆船鞋 的分類器
# Training score : 0.9999364494296337
# 準確率 : 0.9997140406062339
# [[3496    0]
#  [   1    0]]
# 這是 鍊條包 的分類器
# Training score : 1.0
# 準確率 : 0.9997140406062339
# [[3496    0]
#  [   1    0]]
# 這是 拓特包 的分類器
# Training score : 0.9999682247148168
# 準確率 : 1.0
# [[3497]]
# 這是 短鞋 的分類器
# Training score : 0.9999364494296337
# 準確率 : 0.9988561624249357
# [[3493    1]
#  [   3    0]]
# 這是 跟靴 的分類器
# Training score : 0.9999364494296337
# 準確率 : 0.9997140406062339
# [[3496    0]
#  [   1    0]]
# 這是 蛋糕鞋 的分類器
# Training score : 0.9999046741444505
# 準確率 : 1.0
# [[3497]]
# 這是 豆豆鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3497]]
# 這是 艾瑪包 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3497]]
# 這是 情侶鞋 的分類器
# Training score : 0.9999682247148168
# 準確率 : 1.0
# [[3497]]
# 這是 運動鞋 的分類器
# Training score : 0.9999682247148168
# 準確率 : 1.0
# [[3496    0]
#  [   0    1]]
# 這是 瑪麗珍鞋 的分類器
# Training score : 1.0
# 準確率 : 1.0
# [[3497]]

# %%
print("Average Training Score: ", avg_train_score)
print("Average Accuracy Score: ", avg_acc_score)

print("Training Score為1的Tag數:", NumberOfScore1)
print("樣本數不足的Tag")
for i in TagDictionary.keys():
    if sum(TagDictionary[i]) <= 3:
        print(i)
# Out:
# Average Training Score:  0.9896662233257832
# Average Accuracy Score:  0.971649168675191
# Training Score為1的Tag數: 17
# 樣本數不足的Tag
# 菱格紋包
# 帆布鞋
# 黛妃包
# 凱莉包
# 餅乾鞋
# 尖頭靴
# 馬丁靴
# 方頭鞋
# 劍橋包
# NG包
# 腋下包
# 柏金包
# 藤編包
# 鍊條包
# 豆豆鞋
# 艾瑪包
# 情侶鞋
# 瑪麗珍鞋

# %% [markdown]
# ## 後兩年驗證Season 4 (10-12月)(2020-2021)

# %%
test = get_season(combinedWithProduct, 2020, 4)
for i in range(2021, 2022, 1):
    a = get_season(combinedWithProduct, i, 4)
    test = pd.concat([test, a])
TestSeason4 = test.dropna()

TestSeason4 = AgeCoding(TestSeason4)
TestSeason4["SalesLog"] = np.log(TestSeason4["sales"])
TestSeason4["ReviseMemberCardLevel"] = TestSeason4["MemberCardLevel"] / 10

TestTagDictionary = GetTag(TestSeason4, ProductTag)

avg_acc = Backtesting(ResultSeason4, TagDictionary, TestSeason4, TestTagDictionary)
print("Average Accuracy Score: ", avg_acc)
# Out:
# 2020-10-01 2021-01-01
# 2021-10-01 2022-01-01
# 這是 小白鞋 的分類器
# 後兩年驗證準確率 : 0.8199318821264623
# [[15943  1549]
#  [ 2099   668]]
# 這是 菱格紋包 的分類器
# 後兩年驗證準確率 : 0.9924478009773434
# [[20106     0]
#  [  153     0]]
# 這是 鞋用配件 的分類器
# 後兩年驗證準確率 : 0.8796090626388272
# [[17181  1673]
#  [  766   639]]
# 這是 短靴 的分類器
# 後兩年驗證準確率 : 0.6757490498050249
# [[11279  2392]
#  [ 4177  2411]]
# 這是 拖鞋 的分類器
# 後兩年驗證準確率 : 0.8212152623525347
# [[16636     8]
#  [ 3614     1]]
# 這是 贈品 的分類器
# 後兩年驗證準確率 : 0.8207710153512019
# [[10100  2576]
#  [ 1055  6528]]
# 這是 跟鞋 的分類器
# 後兩年驗證準確率 : 0.943531270052816
# [[19088   349]
#  [  795    27]]
# 這是 婚鞋 的分類器
# 後兩年驗證準確率 : 0.9763068265955871
# [[19772   229]
#  [  251     7]]
# 這是 膝靴 的分類器
# 後兩年驗證準確率 : 0.8862234068808924
# [[17470  1382]
#  [  923   484]]
# 這是 NG鞋 的分類器
# 後兩年驗證準確率 : 0.9914605854188262
# [[20082    33]
#  [  140     4]]
# 這是 身體保養 的分類器
# 後兩年驗證準確率 : 0.9137173601855966
# [[18238   998]
#  [  750   273]]
# 這是 鞋墊 的分類器
# 後兩年驗證準確率 : 0.888148477220001
# [[17272  1122]
#  [ 1144   721]]
# 這是 老爹鞋 的分類器
# 後兩年驗證準確率 : 0.9734932622538132
# [[19713    45]
#  [  492     9]]
# 這是 涼拖鞋 的分類器
# 後兩年驗證準確率 : 0.9630287773335308
# [[19509    17]
#  [  732     1]]
# 這是 穆勒鞋 的分類器
# 後兩年驗證準確率 : 0.9565625154252431
# [[19362    61]
#  [  819    17]]
# 這是 牛津鞋 的分類器
# 後兩年驗證準確率 : 0.9751221679253665
# [[19755    29]
#  [  475     0]]
# 這是 日用品 的分類器
# 後兩年驗證準確率 : 0.9643121575596031
# [[19507    79]
#  [  644    29]]
# 這是 厚底鞋 的分類器
# 後兩年驗證準確率 : 0.9980255688829656
# [[20219     2]
#  [   38     0]]
# 這是 尖頭鞋 的分類器
# 後兩年驗證準確率 : 0.9034996791549434
# [[18172   441]
#  [ 1514   132]]
# 這是 帆布鞋 的分類器
# 後兩年驗證準確率 : 0.9858828175132041
# [[19973     0]
#  [  286     0]]
# 這是 涼鞋 的分類器
# 後兩年驗證準確率 : 0.9344982476923837
# [[18761   196]
#  [ 1131   171]]
# 這是 長靴 的分類器
# 後兩年驗證準確率 : 0.9406189841551903
# [[19053    23]
#  [ 1180     3]]
# 這是 襪靴 的分類器
# 後兩年驗證準確率 : 0.8976257465817661
# [[17981   436]
#  [ 1638   204]]
# 這是 便鞋 的分類器
# 後兩年驗證準確率 : 0.9853398489560196
# [[19960    98]
#  [  199     2]]
# 這是 平底鞋 的分類器
# 後兩年驗證準確率 : 0.9328199812429044
# [[18854   336]
#  [ 1025    44]]
# 這是 小包 的分類器
# 後兩年驗證準確率 : 0.9952120045411915
# [[20161    15]
#  [   82     1]]
# 這是 皮夾x卡夾x零錢包 的分類器
# 後兩年驗證準確率 : 0.9722098820277407
# [[19693    13]
#  [  550     3]]
# 這是 紳士鞋 的分類器
# 後兩年驗證準確率 : 0.9378547805913421
# [[18989    60]
#  [ 1199    11]]
# 這是 服裝衣物 的分類器
# 後兩年驗證準確率 : 0.9292660052322425
# [[18698   201]
#  [ 1232   128]]
# 這是 懶人鞋 的分類器
# 後兩年驗證準確率 : 0.9359297102522336
# [[18920   580]
#  [  718    41]]
# 這是 休閒鞋 的分類器
# 後兩年驗證準確率 : 0.9852904881780937
# [[19960    68]
#  [  230     1]]
# 這是 包鞋 的分類器
# 後兩年驗證準確率 : 0.9613998716619774
# [[19466   189]
#  [  593    11]]
# 這是 飾品配件 的分類器
# 後兩年驗證準確率 : 0.9761093834838837
# [[19744    87]
#  [  397    31]]
# 這是 黛妃包 的分類器
# 後兩年驗證準確率 : 0.9953600868749691
# [[20165     0]
#  [   94     0]]
# 這是 包用配件 的分類器
# 後兩年驗證準確率 : 0.9746285601461079
# [[19720    66]
#  [  448    25]]
# 這是 凱莉包 的分類器
# 後兩年驗證準確率 : 0.9967915494348191
# [[20194     0]
#  [   65     0]]
# 這是 高跟鞋 的分類器
# 後兩年驗證準確率 : 0.9744804778123303
# [[19736   115]
#  [  402     6]]
# 這是 草編鞋 的分類器
# 後兩年驗證準確率 : 0.9893874327459401
# [[20043    48]
#  [  167     1]]
# 這是 踝靴 的分類器
# 後兩年驗證準確率 : 0.9790710301594353
# [[19832    96]
#  [  328     3]]
# 這是 雪靴 的分類器
# 後兩年驗證準確率 : 0.9094229725060466
# [[18400  1464]
#  [  371    24]]
# 這是 水桶包 的分類器
# 後兩年驗證準確率 : 0.9941754282047485
# [[20141    14]
#  [  104     0]]
# 這是 餅乾鞋 的分類器
# 後兩年驗證準確率 : 0.9888938249666814
# [[20034     0]
#  [  225     0]]
# 這是 軍靴 的分類器
# 後兩年驗證準確率 : 0.9519719630781381
# [[19286     5]
#  [  968     0]]
# 這是 提袋 的分類器
# 後兩年驗證準確率 : 0.9810454612764697
# [[19871    45]
#  [  339     4]]
# 這是 尖頭靴 的分類器
# 後兩年驗證準確率 : 0.9995557529986673
# [[20250     0]
#  [    9     0]]
# 這是 馬丁靴 的分類器
# 後兩年驗證準確率 : 0.9923490794214916
# [[20104     0]
#  [  155     0]]
# 這是 肩背包 的分類器
# 後兩年驗證準確率 : 0.9998025568882966
# [[20255     4]
#  [    0     0]]
# 這是 娃娃鞋 的分類器
# 後兩年驗證準確率 : 0.9825262846142455
# [[19901   103]
#  [  251     4]]
# 這是 腰包 的分類器
# 後兩年驗證準確率 : 0.9929907695345279
# [[20116    34]
#  [  108     1]]
# 這是 低跟鞋 的分類器
# 後兩年驗證準確率 : 0.9838096648403178
# [[19929    52]
#  [  276     2]]
# 這是 多功能包 的分類器
# 後兩年驗證準確率 : 0.9899797620810504
# [[20053    27]
#  [  176     3]]
# 這是 方包 的分類器
# 後兩年驗證準確率 : 0.9884002171874229
# [[20022    19]
#  [  216     2]]
# 這是 雨靴 的分類器
# 後兩年驗證準確率 : 0.9878572486302384
# [[20008    68]
#  [  178     5]]
# 這是 方頭鞋 的分類器
# 後兩年驗證準確率 : 0.9901772051927539
# [[20060     0]
#  [  199     0]]
# 這是 後背包 的分類器
# 後兩年驗證準確率 : 0.9946690359840071
# [[20151    22]
#  [   86     0]]
# 這是 休閒包 的分類器
# 後兩年驗證準確率 : 0.9960017769880053
# [[20177     2]
#  [   79     1]]
# 這是 莫卡辛鞋 的分類器
# 後兩年驗證準確率 : 0.9924478009773434
# [[20105    43]
#  [  110     1]]
# 這是 劍橋包 的分類器
# 後兩年驗證準確率 : 0.9997531961103707
# [[20254     0]
#  [    5     0]]
# 這是 鞋拔 的分類器
# 後兩年驗證準確率 : 0.9978281257712621
# [[20214    10]
#  [   34     1]]
# 這是 相機包 的分類器
# 後兩年驗證準確率 : 0.993977985093045
# [[20137     0]
#  [  122     0]]
# 這是 NG包 的分類器
# 後兩年驗證準確率 : 0.999654474554519
# [[20252     0]
#  [    7     0]]
# 這是 編織包 的分類器
# 後兩年驗證準確率 : 0.9993583098869638
# [[20246     0]
#  [   13     0]]
# 這是 球鞋 的分類器
# 後兩年驗證準確率 : 0.9859815390690557
# [[19975   226]
#  [   58     0]]
# 這是 腋下包 的分類器
# 後兩年驗證準確率 : 0.9994570314428155
# [[20248     0]
#  [   11     0]]
# 這是 樂福鞋 的分類器
# 後兩年驗證準確率 : 0.9990127844414828
# [[20239    15]
#  [    5     0]]
# 這是 柏金包 的分類器
# 後兩年驗證準確率 : 0.9980255688829656
# [[20219     0]
#  [   40     0]]
# 這是 童鞋 的分類器
# 後兩年驗證準確率 : 0.999654474554519
# [[20252     1]
#  [    6     0]]
# 這是 托特包 的分類器
# 後兩年驗證準確率 : 0.998963423663557
# [[20238     3]
#  [   18     0]]
# 這是 流蘇包 的分類器
# 後兩年驗證準確率 : 1.0
# [[20259]]
# 這是 摺疊鞋 的分類器
# 後兩年驗證準確率 : 0.9997038353324449
# [[20253     6]
#  [    0     0]]
# 這是 藤編包 的分類器
# 後兩年驗證準確率 : 1.0
# [[20259]]
# 這是 馬鞍包 的分類器
# 後兩年驗證準確率 : 0.9992102275531862
# [[20243     1]
#  [   15     0]]
# 這是 機車靴 的分類器
# 後兩年驗證準確率 : 0.9991608667752604
# [[20242    15]
#  [    2     0]]
# 這是 機車包 的分類器
# 後兩年驗證準確率 : 0.9999506392220742
# [[20258     1]
#  [    0     0]]
# 這是 工程靴 的分類器
# 後兩年驗證準確率 : 1.0
# [[20259]]
# 這是 慢跑鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[20259]]
# 這是 帆船鞋 的分類器
# 後兩年驗證準確率 : 0.9998519176662224
# [[20256     0]
#  [    3     0]]
# 這是 鍊條包 的分類器
# 後兩年驗證準確率 : 1.0
# [[20259]]
# 這是 拓特包 的分類器
# 後兩年驗證準確率 : 1.0
# [[20259]]
# 這是 短鞋 的分類器
# 後兩年驗證準確率 : 0.9978774865491881
# [[20216     3]
#  [   40     0]]
# 這是 跟靴 的分類器
# 後兩年驗證準確率 : 1.0
# [[20259]]
# 這是 蛋糕鞋 的分類器
# 後兩年驗證準確率 : 0.9999506392220742
# [[20258     0]
#  [    1     0]]
# 這是 豆豆鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[20259]]
# 這是 艾瑪包 的分類器
# 後兩年驗證準確率 : 1.0
# [[20259]]
# 這是 情侶鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[20259]]
# 這是 運動鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[20259]]
# 這是 瑪麗珍鞋 的分類器
# 後兩年驗證準確率 : 1.0
# [[20259]]
# Average Accuracy Score:  0.969038877569952

# %% [markdown]
# ### Season 4 預測

# %%
pre = get_season(combinedWithProduct, 2021, 1)
PredictSeason4 = pre.dropna()

PredictSeason4 = AgeCoding(PredictSeason4)
PredictSeason4["SalesLog"] = np.log(PredictSeason4["sales"])
PredictSeason4["ReviseMemberCardLevel"] = PredictSeason4["MemberCardLevel"] / 10
# Out:
# 2021-01-01 2021-04-01

# %%
PredictSeason4.head(3)
# Out:
#                           MemberCardLevel  Gender  Age  order  orderSlave  \
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==               30  Female    3      4          16
# 5aRn4GBf1opsUUHmYIKYUQ==               30  Female    4      9          29
# AlyUS7LorP1qdJwahdia0w==               20  Female    3      1           1
#
#                           low  normal  high  sales  \
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==    4       8     4  21384
# 5aRn4GBf1opsUUHmYIKYUQ==   15      14     0  23090
# AlyUS7LorP1qdJwahdia0w==    0       1     0   1406
#
#                                                 SalePageId     avgSales  \
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==                    短靴/帆布鞋/帆布鞋/贈品/  5346.000000
# 5aRn4GBf1opsUUHmYIKYUQ==  襪靴/襪靴/贈品/贈品/尖頭鞋/方包/服裝衣物/尖頭鞋/小白鞋/  2565.555556
# AlyUS7LorP1qdJwahdia0w==                               涼鞋/  1406.000000
#
#                            SalesLog  ReviseMemberCardLevel
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==   9.970398                    3.0
# 5aRn4GBf1opsUUHmYIKYUQ==  10.047155                    3.0
# AlyUS7LorP1qdJwahdia0w==   7.248504                    2.0

# %%
Predicting(ResultSeason4, TagDictionary, PredictSeason4,0)
Predicting(ResultSeason4, TagDictionary, PredictSeason4,1)
Predicting(ResultSeason4, TagDictionary, PredictSeason4,2)
# Out:
# 第1位會員 183befUhGBlsXXVQsFUqmQ==
# 推薦商品 : 膝靴
# Training score : 0.975882558545963
# 第2位會員 5aRn4GBf1opsUUHmYIKYUQ==
# 推薦商品 : 贈品
# Training score : 0.943853071081313
# 第3位會員 AlyUS7LorP1qdJwahdia0w==
# 推薦商品 : []
# Training score : 0

# %% [markdown]
# ### 結帳率 2021

# %%
members = pd.read_csv('91APP_MemberData.csv')
season1 = pd.read_csv('season_1.csv')
season2 = pd.read_csv('season_2.csv')
season3 = pd.read_csv('season_3.csv')
season4 = pd.read_csv('season_4.csv')

# %%
member_c = list(set(members['MemberId'].dropna()))
UnifiedUserIds = ['183befUhGBlsXXVQsFUqmQ==','5aRn4GBf1opsUUHmYIKYUQ==','AlyUS7LorP1qdJwahdia0w==']
print(len(member_c))
# Out:
# 425287

# %% [markdown]
# ### Season 1

# %%
behaviors = season1
avgRatio = 0

temp = behaviors[behaviors["Behavior"] == 'purchase'].dropna()
print("Numbers of Buyer:", len(set(temp['MemberId'])))

purchase = len(behaviors[behaviors["Behavior"] == 'purchase'])
add = len(behaviors[behaviors["Behavior"] == 'add'])
avgRatio = round(purchase / add, 2)
print("Average Ratio:", avgRatio)

for i in UnifiedUserIds:
    memberId = list(set(members[members["UnifiedUserId"] == i]['MemberId'].to_list()))[0]
    temp = behaviors[behaviors["MemberId"] == memberId].dropna()
    purchase = len(temp[temp["Behavior"] == 'purchase'])
    add = len(temp[temp["Behavior"] == 'add'])
    if add != 0:
        ratio = round(purchase / add, 2)
    else:
        ratio = 0
    print('MemberId: ', memberId)
    print("Season: ", 1)
    print('Purchase: ', purchase)
    print('AddToCart: ', add)
    if ratio > avgRatio:
        print('Above')
    elif ratio < avgRatio:
        print('Below')
    else:
        print('Average')
    print('=======================================================')
# Out:
# Numbers of Buyer: 13592
# Average Ratio: 0.29
# MemberId:  5Bd73SAeGSyFaSgcyBGuTO7D09mWqKXefycVfosJGgc=
# Season:  1
# Purchase:  3
# AddToCart:  25
# Below
# =======================================================
# MemberId:  ZLno3QlClWoO9qsKcpKBK7tfjCEolP80D8ddS/zGDa4=
# Season:  1
# Purchase:  7
# AddToCart:  10
# Above
# =======================================================
# MemberId:  WyLJCYsILh5wgrUtPG2x5yK44TnoxTIu3GTQpKXFkFU=
# Season:  1
# Purchase:  1
# AddToCart:  1
# Above
# =======================================================

# %% [markdown]
# ### Season 2

# %%
behaviors = season2
avgRatio = 0

temp = behaviors[behaviors["Behavior"] == 'purchase'].dropna()
print("Numbers of Buyer:", len(set(temp['MemberId'])))

purchase = len(behaviors[behaviors["Behavior"] == 'purchase'])
add = len(behaviors[behaviors["Behavior"] == 'add'])
avgRatio = round(purchase / add, 2)
print("Average Ratio:", avgRatio)

for i in UnifiedUserIds:
    memberId = list(set(members[members["UnifiedUserId"] == i]['MemberId'].to_list()))[0]
    temp = behaviors[behaviors["MemberId"] == memberId].dropna()
    purchase = len(temp[temp["Behavior"] == 'purchase'])
    add = len(temp[temp["Behavior"] == 'add'])
    if add != 0:
        ratio = round(purchase / add, 2)
    else:
        ratio = 0
    print('MemberId: ', memberId)
    print("Season: ", 2)
    print('Purchase: ', purchase)
    print('AddToCart: ', add)
    if ratio > avgRatio:
        print('Above')
    elif ratio < avgRatio:
        print('Below')
    else:
        print('Average')
    print('=======================================================')
# Out:
# Numbers of Buyer: 9548
# Average Ratio: 0.27
# MemberId:  5Bd73SAeGSyFaSgcyBGuTO7D09mWqKXefycVfosJGgc=
# Season:  2
# Purchase:  12
# AddToCart:  24
# Above
# =======================================================
# MemberId:  ZLno3QlClWoO9qsKcpKBK7tfjCEolP80D8ddS/zGDa4=
# Season:  2
# Purchase:  0
# AddToCart:  0
# Below
# =======================================================
# MemberId:  WyLJCYsILh5wgrUtPG2x5yK44TnoxTIu3GTQpKXFkFU=
# Season:  2
# Purchase:  1
# AddToCart:  0
# Below
# =======================================================

# %% [markdown]
# ### Season 3

# %%
behaviors = season3
avgRatio = 0

temp = behaviors[behaviors["Behavior"] == 'purchase'].dropna()
print("Numbers of Buyer:", len(set(temp['MemberId'])))

purchase = len(behaviors[behaviors["Behavior"] == 'purchase'])
add = len(behaviors[behaviors["Behavior"] == 'add'])
avgRatio = round(purchase / add, 2)
print("Average Ratio:", avgRatio)

for i in UnifiedUserIds:
    memberId = list(set(members[members["UnifiedUserId"] == i]['MemberId'].to_list()))[0]
    temp = behaviors[behaviors["MemberId"] == memberId].dropna()
    purchase = len(temp[temp["Behavior"] == 'purchase'])
    add = len(temp[temp["Behavior"] == 'add'])
    if add != 0:
        ratio = round(purchase / add, 2)
    else:
        ratio = 0
    print('MemberId: ', memberId)
    print("Season: ", 3)
    print('Purchase: ', purchase)
    print('AddToCart: ', add)
    if ratio > avgRatio:
        print('Above')
    elif ratio < avgRatio:
        print('Below')
    else:
        print('Average')
    print('=======================================================')
# Out:
# Numbers of Buyer: 10173
# Average Ratio: 0.25
# MemberId:  5Bd73SAeGSyFaSgcyBGuTO7D09mWqKXefycVfosJGgc=
# Season:  3
# Purchase:  1
# AddToCart:  10
# Below
# =======================================================
# MemberId:  ZLno3QlClWoO9qsKcpKBK7tfjCEolP80D8ddS/zGDa4=
# Season:  3
# Purchase:  3
# AddToCart:  3
# Above
# =======================================================
# MemberId:  WyLJCYsILh5wgrUtPG2x5yK44TnoxTIu3GTQpKXFkFU=
# Season:  3
# Purchase:  2
# AddToCart:  4
# Above
# =======================================================

# %% [markdown]
# ### Season 4

# %%
behaviors = season4
avgRatio = 0

temp = behaviors[behaviors["Behavior"] == 'purchase'].dropna()
print("Numbers of Buyer:", len(set(temp['MemberId'])))

purchase = len(behaviors[behaviors["Behavior"] == 'purchase'])
add = len(behaviors[behaviors["Behavior"] == 'add'])
avgRatio = round(purchase / add, 2)
print("Average Ratio:", avgRatio)

for i in UnifiedUserIds:
    memberId = list(set(members[members["UnifiedUserId"] == i]['MemberId'].to_list()))[0]
    temp = behaviors[behaviors["MemberId"] == memberId].dropna()
    purchase = len(temp[temp["Behavior"] == 'purchase'])
    add = len(temp[temp["Behavior"] == 'add'])
    if add != 0:
        ratio = round(purchase / add, 2)
    else:
        ratio = 0
    print('MemberId: ', memberId)
    print("Season: ", 4)
    print('Purchase: ', purchase)
    print('AddToCart: ', add)
    if ratio > avgRatio:
        print('Above')
    elif ratio < avgRatio:
        print('Below')
    else:
        print('Average')
    print('=======================================================')
# Out:
# Numbers of Buyer: 13960
# Average Ratio: 0.23
# MemberId:  5Bd73SAeGSyFaSgcyBGuTO7D09mWqKXefycVfosJGgc=
# Season:  4
# Purchase:  9
# AddToCart:  48
# Below
# =======================================================
# MemberId:  ZLno3QlClWoO9qsKcpKBK7tfjCEolP80D8ddS/zGDa4=
# Season:  4
# Purchase:  2
# AddToCart:  5
# Above
# =======================================================
# MemberId:  WyLJCYsILh5wgrUtPG2x5yK44TnoxTIu3GTQpKXFkFU=
# Season:  4
# Purchase:  2
# AddToCart:  11
# Below
# =======================================================

# %% [markdown]
# ### 人物特徵

# %%
ids = ['183befUhGBlsXXVQsFUqmQ==','5aRn4GBf1opsUUHmYIKYUQ==','AlyUS7LorP1qdJwahdia0w==']
display(ResultSeason1[(ResultSeason1.index == ids[0])])
display(ResultSeason1[(ResultSeason1.index == ids[1])])
display(ResultSeason1[(ResultSeason1.index == ids[2])])
# Out:
#                           MemberCardLevel  Gender  Age  order  orderSlave  \
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==               30  Female    3     29         157
#
#                           low  normal  high  sales  \
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==  115      34     8  99233
#
#                                                                  SalePageId  \
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==  穆勒鞋/贈品/鞋用配件/娃娃鞋/踝靴/短靴/鞋墊/贈品/雨靴/鞋墊/日用品/尖頭鞋/鞋墊/贈...
#
#                              avgSales   SalesLog  ReviseMemberCardLevel
# UnifiedUserId
# 183befUhGBlsXXVQsFUqmQ==  3421.827586  11.505226                    3.0
#                           MemberCardLevel  Gender  Age  order  orderSlave  \
# UnifiedUserId
# 5aRn4GBf1opsUUHmYIKYUQ==               30  Female    4      1           1
# 5aRn4GBf1opsUUHmYIKYUQ==               30  Female    4      4          16
# 5aRn4GBf1opsUUHmYIKYUQ==               30  Female    4      3           9
#
#                           low  normal  high  sales    SalePageId  avgSales  \
# UnifiedUserId
# 5aRn4GBf1opsUUHmYIKYUQ==    1       0     0    999           涼鞋/     999.0
# 5aRn4GBf1opsUUHmYIKYUQ==    4      12     0  15532  贈品/涼鞋/涼鞋/涼鞋/    3883.0
# 5aRn4GBf1opsUUHmYIKYUQ==    6       3     0   6078  贈品/鞋用配件/凱莉包/    2026.0
#
#                           SalesLog  ReviseMemberCardLevel
# UnifiedUserId
# 5aRn4GBf1opsUUHmYIKYUQ==  6.906755                    3.0
# 5aRn4GBf1opsUUHmYIKYUQ==  9.650658                    3.0
# 5aRn4GBf1opsUUHmYIKYUQ==  8.712431                    3.0
#                           MemberCardLevel  Gender  Age  order  orderSlave  \
# UnifiedUserId
# AlyUS7LorP1qdJwahdia0w==               20  Female    3      2           4
#
#                           low  normal  high  sales SalePageId  avgSales  \
# UnifiedUserId
# AlyUS7LorP1qdJwahdia0w==    2       2     0   3160    贈品/小白鞋/    1580.0
#
#                           SalesLog  ReviseMemberCardLevel
# UnifiedUserId
# AlyUS7LorP1qdJwahdia0w==  8.058327                    2.0
